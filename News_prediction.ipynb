# %%
import pandas as pd
import numpy as np
import jieba
import re
dataset=pd.read_csv("train.csv")
dataset.columns=['id','content','comment_all','label']
dataset=dataset.set_index('id')
dataset
# Out:
#                                                  content  \
# id
# 9982   \t\t#王嘉尔##热血街舞团# 王嘉尔或因加盟爱奇艺《热血街舞团》遭优酷全面封杀，目前优酷...
# 9983   谁的群最多，帮忙转一下，找一名弥度职中学生，叫刘冻雪，16岁，请速回鲁甸县医院，妈妈伤的很严...
# 9984   \t\t妈蛋，以色列在战术层面的这些神操作真是令人叹为观止 以战机以俄罗斯战机为掩护并释放电...
# 9985   帮朋友转的，急找孩子，求转，求帮忙寻人启事13940292999。有线索酬金10万，今天上午...
# 9986   \t\t#不情愿的新娘# 看的吻戏最多的一部泰剧从第一集到第四集数不清哈哈哈哈虽然是沙雕剧情...
# ...                                                  ...
# 49905  \t\t网传是实习生误删…这个我是不信的（实习生哪来的权限），希望不要有太多技术人员背锅//...
# 49906  北京时间3月12日消息，在83版《西游记》中扮演孙悟空的演员六小龄童（章金莱），3月12日早...
# 49907                             学生举报学校雾霾天上课却被教育局泄露电话号码
# 49908  \t\t惊！国民儿子某蛙光天化日之下脚踩两只船！对此，记者采访到近日刚刚结束电影《鼠来宝3》...
# 49909  \t  &#xe627; 张继科 小周：偷偷告诉你们，继科对签名照的照片很满意拿走了几张（觉...
#
#                                              comment_all  label
# id
# 9982   不想理你，大家不要供献热度，谣言止于智者\t优酷和汪涵合作深入，而何炅一直特别挺王嘉尔，这…...      0
# 9983                                                 NaN     -1
# 9984                                                 NaN      0
# 9985   你受骗上当了，这是虚假消息！请看辟谣网址（O谣场现形记）。尽快删除帖子，因为已被举报。\t回...     -1
# 9986                                  后面要虐[泪]\t都在哪里看的?\t      0
# ...                                                  ...    ...
# 49905                                                NaN      0
# 49906  这是假消息的嘛\t回复@顔鋭:真的\t[蜡烛][蜡烛]1[蜡烛]2\t是假的，当事人还在网上...     -1
# 49907                                                NaN      1
# 49908                                                NaN      0
# 49909  小周是谁[允悲]1[允悲]\t哈哈哈，想不到吧[允悲]\t你够啦@张继科;;[挖鼻]1[挖鼻...      0
#
# [39928 rows x 3 columns]

# %% [markdown]
# 以上是初始数据集

# %%
test=pd.read_csv("test.csv")
test.columns=['id','content','comment_all']
test=test.set_index('id')
testset=test
testset
# Out:
#                                                 content  \
# id
# 0     \t\t昨天在家楼下网点改了全渠道手机号，去单位楼下用专机表扬了大堂经理，并称不需要回复。今...
# 1     【婆婆为维护出轨儿子虐待儿媳致其成”骷髅“】杨女士发现老公出轨，向婆婆反映。婆婆辩称“男人都...
# 2     各位，有家长反映:今天中午放学时，有学生遇到开小车的向小学生问路，并拿出100元感谢费，让小...
# 3     帮忙发一条救命信息。急需rh阴性血，救命之恩必有重谢。电话13845672513155616...
# 4                             “逃犯克星”4立新功!张学友金华演唱会又有逃犯被抓
# ...                                                 ...
# 9977  \t  #历史影像# 中英街边界石碑上，殖民香港的英国警官与解放军对峙，美国杂志 LIFE ...
# 9978  【开学季我们进校园】新年已过，转眼又到了孩子们开学的时候，为守护辖区师生校园安全，经济开发区...
# 9979  一名中学生，叫周榆棍，17岁，请速回平山县医院，妈妈伤的很严重，想见她最后一面，爸爸号码：1...
# 9980  艺龙真是恶心人，我在艺龙定了好几次宾馆，每次都说给我按照约定返现，可是一次都没有兑现，找各种...
# 9981  学生家长捡到一个高考准考证，谁认识通知下，别耽误了高考大事。白娅倩考点一中考场013座号11...
#
#                                             comment_all
# id
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3      此为虚假消息！请勿转发虚假消息！\t回复@花自漂零的天空:你知道什么你就举报我，闲在难受的啊\t
# 4                                                   NaN
# ...                                                 ...
# 9977                                                NaN
# 9978                                                NaN
# 9979                                                NaN
# 9980  您好，感谢反馈，会尽快与您联系\t的时候是问清楚酒店工作人员之后入住的，现在又来怪我？艺龙这...
# 9981  @白较瘦@Ctrl键@大鹏看天下转发下吧，别耽误孩子高考[心]\t假消息\t吸金电话不要打\...
#
# [9982 rows x 2 columns]

# %% [markdown]
# dataset.loc[9983,'comment_all']\\
# type(dataset.loc[9983,'comment_all'])\\
# \\float

# %%
def clear(text)->str:
    #print(re.findall('[\u4E00-\u9FFF]+|\d',text))
    if type(text) is float:return 
    str1=""
    str2=str1.join(text)
    y=lambda x:re.findall('[\u4E00-\u9FFF]+',x)
    li=y(str2)
    for i in range(len(li)):
        li[i]=list(jieba.cut(li[i]))
    li2=[]
    for subli in li:
        for item in subli:
            li2.append(item)
    return li2
text='正则365表达\t式ds匹配/--*测\t试文字'
a=clear(dataset.loc[9982,'content'])
b=clear(dataset.loc[9984,'comment_all'])
c=clear(testset.loc[9979,'content'])
print(a)
print(b)
print(c)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/34/5ls3qb4j0rl0kbsw8j22d1_w0000gn/T/jieba.cache
# Loading model cost 0.441 seconds.
# Prefix dict has been built successfully.
# ['王嘉尔', '热血', '街', '舞团', '王嘉尔', '或', '因', '加盟', '爱奇艺', '热血', '街', '舞团', '遭优酷', '全面', '封杀', '目前', '优酷', '视频', '已', '将', '王嘉尔', '的', '相关', '视频', '全面', '下架', '网传', '王嘉尔', '之前', '已', '答应', '录制', '优酷', '这', '就是', '街舞', '合同', '也', '已', '确定', '这次', '究竟', '是', '双方', '争夺', '艺人', '惹出', '事端', '还是', '王嘉尔', '出尔反尔', '你们', '怎么', '看']
# None
# ['一名', '中学生', '叫', '周榆棍', '岁', '请', '速回', '平山县', '医院', '妈妈', '伤', '的', '很', '严重', '想见', '她', '最后', '一面', '爸爸', '号码', '爱心', '接力']

# %%
text="分词测试文字"
a=text.split()
a
# Out:
# ['分词测试文字']

# %%
for index,row in dataset.iterrows():
    dataset.at[index,'content']=clear(dataset.at[index,'content'])
    dataset.at[index,'comment_all']=clear(dataset.at[index,'comment_all'])
dataset
# Out:
#                                                  content  \
# id
# 9982   [王嘉尔, 热血, 街, 舞团, 王嘉尔, 或, 因, 加盟, 爱奇艺, 热血, 街, 舞团...
# 9983   [谁, 的, 群, 最, 多, 帮忙, 转, 一下, 找, 一名, 弥度, 职, 中学生, ...
# 9984   [妈蛋, 以色列, 在, 战术, 层面, 的, 这些, 神, 操作, 真是, 令人, 叹为观...
# 9985   [帮, 朋友, 转, 的, 急, 找, 孩子, 求转, 求, 帮忙, 寻人启事, 有, 线索...
# 9986   [不, 情愿, 的, 新娘, 看, 的, 吻, 戏, 最, 多, 的, 一部, 泰剧, 从,...
# ...                                                  ...
# 49905  [网传, 是, 实习生, 误删, 这个, 我, 是, 不信, 的, 实习生, 哪来, 的, ...
# 49906  [北京, 时间, 月, 日, 消息, 在, 版, 西游记, 中, 扮演, 孙悟空, 的, 演...
# 49907     [学生, 举报, 学校, 雾, 霾, 天, 上课, 却, 被, 教育局, 泄露, 电话号码]
# 49908  [惊, 国民, 儿子, 某蛙, 光天化日, 之下, 脚, 踩, 两只, 船, 对此, 记者,...
# 49909  [张继科, 小, 周, 偷偷, 告诉, 你们, 继科, 对, 签名, 照, 的, 照片, 很...
#
#                                              comment_all  label
# id
# 9982   [不想, 理, 你, 大家, 不要, 供献, 热度, 谣言止于, 智者, 优酷, 和, 汪涵...      0
# 9983                                                None     -1
# 9984                                                None      0
# 9985   [你, 受骗上当, 了, 这是, 虚假, 消息, 请, 看, 辟谣, 网址, 谣场, 现形记...     -1
# 9986                         [后面, 要虐, 泪, 都, 在, 哪里, 看, 的]      0
# ...                                                  ...    ...
# 49905                                               None      0
# 49906  [这是, 假消息, 的, 嘛, 回复, 顔, 鋭, 真的, 蜡烛, 蜡烛, 蜡烛, 是, 假...     -1
# 49907                                               None      1
# 49908                                               None      0
# 49909  [小周, 是, 谁, 允悲, 允悲, 哈哈哈, 想不到, 吧, 允悲, 你够, 啦, 张继科...      0
#
# [39928 rows x 3 columns]

# %% [markdown]
# 用正则表达式来匹配汉字，其中\t作为分隔符应该单独分开？后面想了想，把数字和字符都给去掉了，只留下了汉字。

# %%
dataset2=[]
for index,row in dataset.iterrows():
    str2=" "
    if dataset.loc[index,'comment_all']is None:
        dataset2.append(dataset.loc[index,'content'])
    else:
        dataset2.append(dataset.loc[index,'content']+dataset.loc[index,'comment_all'])

# %%
dataset2
# Out:
# [['王嘉尔',
#   '热血',
#   '街',
#   '舞团',
#   '王嘉尔',
#   '或',
#   '因',
#   '加盟',
#   '爱奇艺',
#   '热血',
#   '街',
#   '舞团',
#   '遭优酷',
#   '全面',
#   '封杀',
#   '目前',
#   '优酷',
#   '视频',
#   '已',
#   '将',
#   '王嘉尔',
#   '的',
#   '相关',
#   '视频',
#   '全面',
#   '下架',
#   '网传',
#   '王嘉尔',
#   '之前',
#   '已',
#   '答应',
#   '录制',
#   '优酷',
#   '这',
#   '就是',
#   '街舞',
#   '合同',
#   '也',
#   '已',
#   '确定',
#   '这次',
#   '究竟',
#   '是',
#   '双方',
#   '争夺',
#   '艺人',
#   '惹出',
#   '事端',
#   '还是',
#   '王嘉尔',
#   '出尔反尔',
#   '你们',
#   '怎么',
#   '看',
#   '不想',
#   '理',
#   '你',
#   '大家',
#   '不要',
#   '供献',
#   '热度',
#   '谣言止于',
#   '智者',
#   '优酷',
#   '和',
#   '汪涵',
#   '合作',
#   '深入',
#   '而',
#   '何炅',
#   '一直',
#   '特别',
#   '挺',
#   '王嘉尔',
#   '这',
#   '不好意思',
#   '我',
#   '在',
#   '瞎',
#   '想',
#   '笑死人',
#   '这个',
#   '营销',
#   '号',
#   '说',
#   '的',
#   '自己',
#   '好像',
#   '亲眼看见',
#   '了',
#   '一样',
#   '真签',
#   '了',
#   '合同',
#   '优酷',
#   '会',
#   '不官',
#   '宣',
#   '吗',
#   '谁',
#   '会',
#   '放过',
#   '这么',
#   '好',
#   '的',
#   '机会',
#   '敢情',
#   '营销',
#   '号',
#   '写',
#   '东西',
#   '都',
#   '是',
#   '这样',
#   '乱写',
#   '经不起',
#   '推敲',
#   '的',
#   '费解',
#   '允悲',
#   '我',
#   '觉得',
#   '腾讯',
#   '芒果',
#   '爱奇艺',
#   '站',
#   '的',
#   '视频',
#   '很',
#   '好看',
#   '吃瓜',
#   '吃瓜',
#   '举报',
#   '一个',
#   '大',
#   '公司',
#   '这么',
#   '针对',
#   '一个',
#   '艺人',
#   '也',
#   '是',
#   '够',
#   '小心眼',
#   '活该',
#   '又',
#   '改成',
#   '这',
#   '就是',
#   '街舞',
#   '了',
#   '是',
#   '吗',
#   '改不完',
#   '的',
#   '名字',
#   '允悲',
#   '我',
#   '还有',
#   '腾讯',
#   '爱奇艺',
#   '站',
#   '芒果',
#   '看',
#   '的',
#   '挺',
#   '好',
#   '的',
#   '连',
#   '你',
#   '也',
#   '发',
#   '合同',
#   '已经',
#   '确定',
#   '这种',
#   '模棱两可',
#   '的',
#   '词',
#   '你',
#   '也',
#   '写',
#   '的',
#   '出来',
#   '我',
#   '另',
#   '一个',
#   '微博号',
#   '关注',
#   '你们',
#   '好久',
#   '了',
#   '失望',
#   '失望',
#   '失望',
#   '别',
#   '乱说',
#   '好',
#   '不',
#   '我',
#   '在',
#   '爱奇艺',
#   '泡泡',
#   '上',
#   '看嘉尔',
#   '行程',
#   '这',
#   '就是',
#   '街舞',
#   '易',
#   '烊',
#   '千玺',
#   '黄子',
#   '韬',
#   '王嘉尔',
#   '节目',
#   '暂定',
#   '并',
#   '没有',
#   '敲下来',
#   '可能',
#   '爱奇艺',
#   '就',
#   '签',
#   '了',
#   '毕竟',
#   '我嘉太火',
#   '你',
#   '优酷',
#   '不',
#   '确定',
#   '还有',
#   '百事',
#   '和',
#   '赞助',
#   '呢',
#   '网传',
#   '合同',
#   '确定',
#   '不',
#   '就是',
#   '你',
#   '这种',
#   '人',
#   '在',
#   '传',
#   '吗'],
#  ['谁',
#   '的',
#   '群',
#   '最',
#   '多',
#   '帮忙',
#   '转',
#   '一下',
#   '找',
#   '一名',
#   '弥度',
#   '职',
#   '中学生',
#   '叫',
#   '刘冻雪',
#   '岁',
#   '请',
#   '速回',
#   '鲁甸县',
#   '医院',
#   '妈妈',
#   '伤',
#   '的',
#   '很',
#   '严重',
#   '想',
#   '最后',
#   '见',
#   '她',
#   '一面',
#   '姐姐',
#   '号码',
#   '爱心',
#   '接力',
#   '不转',
#   '对不起',
#   '自己',
#   '好人',
#   '有',
#   '好',
#   '报',
#   '祥临',
#   '公路'],
#  ['妈蛋',
#   '以色列',
#   '在',
#   '战术',
#   '层面',
#   '的',
#   '这些',
#   '神',
#   '操作',
#   '真是',
#   '令人',
#   '叹为观止',
#   '以',
#   '战机',
#   '以',
#   '俄罗斯',
#   '战机',
#   '为',
#   '掩护',
#   '并',
#   '释放',
#   '电子干扰',
#   '让',
#   '叙军',
#   '的',
#   '俄罗斯',
#   '产',
#   '打中',
#   '了',
#   '俄军',
#   '机',
#   '估计',
#   '连',
#   '俄军',
#   '机上',
#   '的',
#   '识别系统',
#   '也',
#   '一起',
#   '电子干扰',
#   '了',
#   '这招',
#   '以子之矛',
#   '攻子之盾',
#   '用',
#   '得',
#   '狠',
#   '毛子',
#   '知道',
#   '以色列',
#   '在',
#   '耍',
#   '阴',
#   '的',
#   '也',
#   '没',
#   '办法',
#   '以色列',
#   '后面',
#   '站',
#   '着',
#   '美帝',
#   '展开',
#   '全文'],
#  ['帮',
#   '朋友',
#   '转',
#   '的',
#   '急',
#   '找',
#   '孩子',
#   '求转',
#   '求',
#   '帮忙',
#   '寻人启事',
#   '有',
#   '线索',
#   '酬金',
#   '万',
#   '今天上午',
#   '一个三岁',
#   '多',
#   '小女孩',
#   '在',
#   '锦绣',
#   '花园',
#   '小区',
#   '附近',
#   '被',
#   '人',
#   '拐走',
#   '了',
#   '小女孩',
#   '能',
#   '说出',
#   '她',
#   '爸爸',
#   '的',
#   '手机号码',
#   '从',
#   '监控',
#   '上',
#   '看',
#   '是',
#   '被',
#   '一个四十多岁',
#   '男人',
#   '抱',
#   '走现',
#   '大人',
#   '都',
#   '急',
#   '疯',
#   '了',
#   '有',
#   '知情者',
#   '请告',
#   '之',
#   '万分',
#   '感谢',
#   '看到',
#   '信息',
#   '的',
#   '兄弟姐妹',
#   '留意',
#   '一下',
#   '联系人',
#   '宁继春',
#   '你',
#   '受骗上当',
#   '了',
#   '这是',
#   '虚假',
#   '消息',
#   '请',
#   '看',
#   '辟谣',
#   '网址',
#   '谣场',
#   '现形记',
#   '尽快',
#   '删除',
#   '帖子',
#   '因为',
#   '已',
#   '被',
#   '举报',
#   '回复',
#   '花自',
#   '漂零',
#   '的',
#   '天空',
#   '晕',
#   '我',
#   '真的',
#   '不',
#   '知道',
#   '是',
#   '朋友',
#   '在',
#   '微信里',
#   '发',
#   '的',
#   '以前',
#   '是',
#   '同事',
#   '所以',
#   '就',
#   '帮',
#   '她',
#   '转',
#   '了'],
#  ['不',
#   '情愿',
#   '的',
#   '新娘',
#   '看',
#   '的',
#   '吻',
#   '戏',
#   '最',
#   '多',
#   '的',
#   '一部',
#   '泰剧',
#   '从',
#   '第一集',
#   '到',
#   '第四集',
#   '数不清',
#   '哈哈哈哈',
#   '虽然',
#   '是',
#   '沙雕',
#   '剧情',
#   '十年',
#   '前',
#   '晋江',
#   '言情小说',
#   '的',
#   '梗',
#   '但',
#   '完全',
#   '停不下来',
#   '男女',
#   '主甜炸',
#   '啦',
#   '全程',
#   '姨母',
#   '笑',
#   '啊',
#   '后面',
#   '要虐',
#   '泪',
#   '都',
#   '在',
#   '哪里',
#   '看',
#   '的'],
#  ['商界',
#   '大',
#   '搜罗',
#   '滴滴',
#   '司机',
#   '打',
#   '投资人',
#   '张桓',
#   '滴滴',
#   '回应',
#   '称',
#   '抱歉',
#   '很',
#   '震惊',
#   '将',
#   '垫付',
#   '医疗费',
#   '月',
#   '日',
#   '滴滴',
#   '投资人',
#   '张桓自',
#   '曝',
#   '被',
#   '滴滴',
#   '司机',
#   '殴打',
#   '随后',
#   '滴滴',
#   '发布',
#   '声明',
#   '称',
#   '司机',
#   '账户',
#   '已',
#   '被',
#   '紧急',
#   '冻结',
#   '平台',
#   '将',
#   '探望',
#   '张桓',
#   '先生',
#   '并',
#   '垫付',
#   '医疗',
#   '费用',
#   '并',
#   '配合',
#   '警方',
#   '调查',
#   '狡猾',
#   '的',
#   '炒作',
#   '挖',
#   '鼻',
#   '别人',
#   '是',
#   '来',
#   '赚钱',
#   '的',
#   '应该',
#   '有',
#   '别的',
#   '原因',
#   '吧',
#   '滴滴',
#   '很',
#   '震惊',
#   '已',
#   '交由',
#   '律师',
#   '处理',
#   '大',
#   '水冲',
#   '了',
#   '龙王庙',
#   '很',
#   '屌',
#   '哦',
#   '祝贺',
#   '滴滴',
#   '打车',
#   '成功',
#   '研发',
#   '出',
#   '滴滴',
#   '打人',
#   '功能',
#   '二哈',
#   '发生',
#   '过',
#   '那么',
#   '多',
#   '滴滴',
#   '司机',
#   '引发',
#   '的',
#   '恶性',
#   '伤人',
#   '事故',
#   '滴滴',
#   '还',
#   '安然无恙',
#   '可见',
#   '背后',
#   '大树',
#   '很',
#   '高',
#   '啊',
#   '滴滴',
#   '越来越',
#   '像',
#   '垄断性',
#   '国企',
#   '了',
#   '美团',
#   '打车',
#   '什么',
#   '时候',
#   '到',
#   '北京',
#   '啊',
#   '不知',
#   '感恩',
#   '还',
#   '恩将仇报',
#   '可恶',
#   '必须',
#   '严惩不贷',
#   '滴滴',
#   '后台',
#   '很',
#   '厉害',
#   '他',
#   '就',
#   '像',
#   '垄断',
#   '所有',
#   '唯独',
#   '它',
#   '一家',
#   '挣钱',
#   '如今',
#   '滴滴',
#   '外卖',
#   '在',
#   '无锡',
#   '跟',
#   '美团',
#   '饿',
#   '了',
#   '么',
#   '闹',
#   '的',
#   '够',
#   '厉害',
#   '了',
#   '都',
#   '是',
#   '图',
#   '老百姓',
#   '的',
#   '钱',
#   '啊',
#   '没有',
#   '无缘无故',
#   '的',
#   '爱',
#   '投资',
#   '也',
#   '没有',
#   '无缘无故',
#   '的',
#   '恨',
#   '啥',
#   '情况',
#   '你',
#   '是',
#   '不想',
#   '付钱',
#   '吧',
#   '中间',
#   '肯定',
#   '有',
#   '误会',
#   '不然',
#   '能',
#   '无故',
#   '打人'],
#  ['吉林市', '春芽', '中东', '幼儿园', '事件', '就', '怕事', '不', '大'],
#  ['爸爸',
#   '买',
#   '了',
#   '我',
#   '很',
#   '喜欢',
#   '的',
#   '芝士',
#   '蛋糕',
#   '和',
#   '三明治',
#   '可惜',
#   '我',
#   '现在',
#   '什么',
#   '味道',
#   '都',
#   '吃不出来',
#   '也',
#   '闻',
#   '不到',
#   '气味',
#   '嗅觉',
#   '味觉',
#   '完全',
#   '失灵',
#   '有种',
#   '浪费',
#   '食物',
#   '的',
#   '感觉',
#   '我',
#   '还是',
#   '啃',
#   '两块',
#   '西瓜',
#   '去',
#   '睡觉',
#   '吧'],
#  ['平安',
#   '守护',
#   '年',
#   '月',
#   '日晚',
#   '尉氏县',
#   '城一',
#   '白色',
#   '轿车',
#   '闯红灯',
#   '执勤',
#   '的',
#   '尉氏县',
#   '公安局',
#   '交警大队',
#   '民警',
#   '追上去',
#   '拦停',
#   '该车',
#   '对',
#   '驾驶员',
#   '给予',
#   '教育',
#   '和',
#   '处罚',
#   '尉氏',
#   '交警',
#   '提示',
#   '司机',
#   '朋友',
#   '请',
#   '安全',
#   '驾驶',
#   '遵循',
#   '交通法规',
#   '对',
#   '自己',
#   '对',
#   '他人',
#   '的',
#   '安全',
#   '都',
#   '能',
#   '得到',
#   '保证'],
#  ['马',
#   '天宇',
#   '因为',
#   '是',
#   '你',
#   '所以',
#   '我',
#   '相信',
#   '馬',
#   '天宇',
#   '对于',
#   '凉生',
#   '这部',
#   '电视剧',
#   '虽然',
#   '不',
#   '知道',
#   '到底',
#   '发生',
#   '了',
#   '什么',
#   '那些',
#   '说要',
#   '减马',
#   '天宇',
#   '戏份',
#   '的',
#   '谣言',
#   '如果',
#   '是',
#   '真的',
#   '那凉',
#   '生播',
#   '了',
#   '我',
#   '一定',
#   '不会',
#   '看',
#   '虽然',
#   '等',
#   '了',
#   '很',
#   '久',
#   '但',
#   '那',
#   '都',
#   '是因为',
#   '马',
#   '天宇',
#   '也',
#   '仅仅',
#   '因为',
#   '马',
#   '天宇',
#   '还有',
#   '你们',
#   '不要',
#   '再说',
#   '马',
#   '天宇',
#   '怎么',
#   '怎么样',
#   '我',
#   '相信',
#   '我',
#   '喜欢',
#   '的',
#   '人',
#   '是',
#   '一个',
#   '善良',
#   '有',
#   '责任',
#   '的',
#   '人',
#   '他',
#   '怎么样',
#   '不用',
#   '你们',
#   '来',
#   '评判',
#   '所有',
#   '羽毛',
#   '都',
#   '是',
#   '长',
#   '了',
#   '脑子',
#   '的',
#   '人',
#   '自己',
#   '会',
#   '看',
#   '不用',
#   '你们',
#   '在',
#   '旁边',
#   '说三道四',
#   '在',
#   '我们',
#   '眼里',
#   '马',
#   '天宇',
#   '就是',
#   '最',
#   '善良',
#   '最好',
#   '的',
#   '偶像',
#   '他',
#   '带给',
#   '我们',
#   '正',
#   '能量',
#   '引领',
#   '我们',
#   '向上',
#   '不断',
#   '成长',
#   '所以',
#   '请',
#   '不要',
#   '随意',
#   '诋毁',
#   '他',
#   '全民',
#   '比心',
#   '郑州',
#   '郑州'],
#  ['不可思议',
#   '的',
#   '妈妈',
#   '发光',
#   '的',
#   '小天使',
#   '李希侃',
#   '来',
#   '做客',
#   '啦',
#   '狐狸',
#   '哥哥',
#   '和',
#   '宝贝',
#   '们',
#   '的',
#   '奇幻',
#   '旅程',
#   '到底',
#   '发生',
#   '了',
#   '什么',
#   '呢',
#   '跟着',
#   '满分',
#   '微笑',
#   '的',
#   '李希侃',
#   '哥哥',
#   '一起',
#   '畅游',
#   '迪士尼',
#   '乐园',
#   '吧',
#   '今日',
#   '份',
#   '的',
#   '狐狸',
#   '哥哥',
#   '也',
#   '是',
#   '全糖',
#   '超甜',
#   '快',
#   '来',
#   '看看',
#   '我们',
#   '的',
#   '小侃',
#   '哥哥',
#   '阿',
#   '网页',
#   '链接',
#   '狐狸',
#   '哥哥',
#   '超甜',
#   '小朋友',
#   '们',
#   '也',
#   '超甜',
#   '李希侃',
#   '期待',
#   '狐狸',
#   '哥哥',
#   '与',
#   '小朋友',
#   '们',
#   '的',
#   '互动',
#   '李希侃',
#   '网页',
#   '链接',
#   '早',
#   '啊',
#   '阿',
#   '不',
#   '期待',
#   '李希侃',
#   '是',
#   '我们',
#   '超级',
#   '期待',
#   '的',
#   '小侃',
#   '哥哥',
#   '了',
#   '评论',
#   '配图',
#   '羞嗒',
#   '嗒',
#   '宝贝',
#   '好',
#   '甜',
#   '啊',
#   '李希侃',
#   '李希侃',
#   '超话',
#   '超级',
#   '甜',
#   '的',
#   '李希侃',
#   '舔',
#   '屏',
#   '舔',
#   '屏',
#   '期待',
#   '超甜',
#   '的',
#   '狐狸',
#   '哥哥',
#   '评论',
#   '配图',
#   '终于',
#   '快要',
#   '播出',
#   '了',
#   '真的',
#   '好',
#   '期待',
#   '这个',
#   '可爱',
#   '的',
#   '李希侃',
#   '哦',
#   '李希侃',
#   '网页',
#   '链接',
#   '正',
#   '能量',
#   '的',
#   '小',
#   '哥哥',
#   '谁',
#   '不',
#   '爱',
#   '呢',
#   '李希侃',
#   '心',
#   '心',
#   '心',
#   '周四',
#   '会',
#   '准时',
#   '看',
#   '我们',
#   '的',
#   '小侃',
#   '哥哥',
#   '的',
#   '羞嗒',
#   '嗒',
#   '迫不及待',
#   '想',
#   '看',
#   '甜甜的',
#   '狐狸',
#   '哥哥',
#   '期待',
#   '希侃',
#   '的',
#   '表现',
#   '谢谢',
#   '不可思议',
#   '的',
#   '妈妈',
#   '节目',
#   '的',
#   '支持',
#   '李希侃',
#   '李希侃',
#   '超话',
#   '星期四',
#   '八点',
#   '不见不散',
#   '迫不及待',
#   '的',
#   '想要',
#   '看到',
#   '李希侃',
#   '和',
#   '小朋友',
#   '的',
#   '互动',
#   '呢',
#   '期待',
#   '我们',
#   '狐狸',
#   '哥哥',
#   '李希侃',
#   '羞嗒',
#   '嗒',
#   '超甜',
#   '小帅哥',
#   '爱',
#   '你',
#   '李希侃',
#   '查看',
#   '图片',
#   '超',
#   '温柔',
#   '的',
#   '李希侃',
#   '超话',
#   '网页',
#   '链接',
#   '可怜',
#   '可怜',
#   '李希侃',
#   '带',
#   '娃',
#   '啦',
#   '评论',
#   '配图',
#   '周四',
#   '快点',
#   '来',
#   '啊',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '看到',
#   '宝贝',
#   '心情',
#   '都',
#   '好',
#   '了',
#   '周四',
#   '快',
#   '来',
#   '亲亲',
#   '亲亲',
#   '亲亲',
#   '期待',
#   '我们',
#   '小侃',
#   '哥哥',
#   '啦',
#   '是',
#   '个',
#   '温柔',
#   '的',
#   '小',
#   '哥哥',
#   '呢',
#   '评论',
#   '配图',
#   '爱',
#   '你',
#   '努力',
#   '正',
#   '能量',
#   '的',
#   '小侃',
#   '哥哥',
#   '爱',
#   '你',
#   '是',
#   '温柔',
#   '的',
#   '小侃',
#   '哥哥',
#   '没错',
#   '了',
#   '评论',
#   '配图',
#   '羞嗒',
#   '嗒',
#   '羞嗒',
#   '嗒',
#   '羞嗒',
#   '嗒',
#   '李希侃',
#   '啊啊啊',
#   '期待',
#   '小侃',
#   '哥哥',
#   '和',
#   '小朋友',
#   '们',
#   '的',
#   '互动',
#   '评论',
#   '配图',
#   '是',
#   '甜',
#   '如西',
#   '柚汁',
#   '一般',
#   '的',
#   '小',
#   '呀',
#   '评论',
#   '配图',
#   '羞嗒',
#   '嗒',
#   '他',
#   '真的',
#   '好',
#   '温柔',
#   '期待',
#   '后天',
#   '晚上',
#   '滴',
#   '李希侃',
#   '温柔',
#   '帅气',
#   '的',
#   '李希侃',
#   '呀',
#   '评论',
#   '配图',
#   '努力',
#   '正',
#   '能量',
#   '的',
#   '小',
#   '狐狸',
#   '超级',
#   '喜欢'],
#  ['哪來',
#   '全面',
#   '停工',
#   '的',
#   '消息',
#   '經紀',
#   '人',
#   '與',
#   '工作室',
#   '從',
#   '沒',
#   '這樣',
#   '回應',
#   '媒體過',
#   '謠言止',
#   '於',
#   '智者',
#   '可別',
#   '亂',
#   '生事',
#   '美媛',
#   '的',
#   '工作',
#   '照常',
#   '進行',
#   '著',
#   '美媛',
#   '才',
#   '捨',
#   '不得',
#   '可愛的',
#   '粉絲們',
#   '呢',
#   '敬請',
#   '期待',
#   '新',
#   '作品'],
#  ['内蒙古',
#   '观察',
#   '内蒙古',
#   '养老金',
#   '调整',
#   '方案',
#   '正',
#   '待',
#   '批复',
#   '网上',
#   '传闻',
#   '系',
#   '谣言',
#   '近日',
#   '网络',
#   '上',
#   '关于',
#   '我区',
#   '调整',
#   '养老金',
#   '的',
#   '传闻',
#   '越来越',
#   '多',
#   '对此',
#   '内蒙古',
#   '晨报',
#   '全',
#   '媒体',
#   '记者',
#   '从',
#   '内蒙古',
#   '人力资源',
#   '和',
#   '社会保障',
#   '厅',
#   '日前',
#   '召开',
#   '的',
#   '年',
#   '上半年',
#   '新闻',
#   '通气会',
#   '上',
#   '获悉',
#   '内蒙古',
#   '养老金',
#   '调整',
#   '方案',
#   '正',
#   '待',
#   '批复',
#   '网上',
#   '的',
#   '传闻',
#   '均',
#   '属于',
#   '谣言',
#   '回复',
#   '张大',
#   '曦',
#   '的',
#   '赞',
#   '作揖'],
#  ['分享',
#   '网易',
#   '跟贴',
#   '北京',
#   '幼儿园',
#   '被',
#   '曝',
#   '猥亵',
#   '幼童',
#   '家长',
#   '亲手',
#   '将',
#   '孩子',
#   '交给',
#   '禽兽',
#   '来自',
#   '网易',
#   '新闻',
#   '客户端',
#   '网易',
#   '新闻'],
#  ['网传',
#   '李',
#   '文星',
#   '可能',
#   '误入',
#   '传销',
#   '组织',
#   '可',
#   '为什么',
#   '漏洞',
#   '那么',
#   '多',
#   '李',
#   '文星',
#   '还是',
#   '执意',
#   '要',
#   '去',
#   '这家',
#   '上市公司',
#   '这么',
#   '容易',
#   '就',
#   '相信',
#   '他',
#   '已经',
#   '找',
#   '了',
#   '很',
#   '久',
#   '的',
#   '工作',
#   '了',
#   '想',
#   '从事',
#   '工作',
#   '经过',
#   '突击',
#   '学习',
#   '后',
#   '就',
#   '开始',
#   '找',
#   '工作',
#   '了',
#   '几个',
#   '月',
#   '的',
#   '求职',
#   '煎熬',
#   '北京',
#   '科蓝',
#   '的',
#   '通知',
#   '成',
#   '了',
#   '他',
#   '的',
#   '救命稻草',
#   '有人',
#   '说',
#   '某',
#   '招聘',
#   '平台',
#   '害死',
#   '了',
#   '李',
#   '文星',
#   '但',
#   '我',
#   '认为',
#   '还',
#   '那',
#   '平凡',
#   '的',
#   '梦想',
#   '不是',
#   '那么',
#   '容易',
#   '干',
#   '的',
#   '希望',
#   '各',
#   '招聘',
#   '平台',
#   '加上',
#   '对',
#   '入驻',
#   '企业',
#   '真实性',
#   '的',
#   '核实',
#   '不是',
#   '可能',
#   '是',
#   '就是',
#   '这',
#   '肯定',
#   '是',
#   '传销',
#   '希望',
#   '这血',
#   '的',
#   '教训',
#   '能够',
#   '引起',
#   '有关',
#   '部门',
#   '的',
#   '重视'],
#  ['妇幼保健',
#   '院',
#   '提示',
#   '您',
#   '请',
#   '不要',
#   '给',
#   '宝宝',
#   '喝',
#   '爽歪歪',
#   '和',
#   '有',
#   '添加剂',
#   '的',
#   '牛奶',
#   '饮料',
#   '告诉',
#   '家里',
#   '有',
#   '小孩',
#   '的',
#   '朋友',
#   '刚看',
#   '了',
#   '新闻',
#   '可口可乐',
#   '爽歪歪',
#   '娃哈哈',
#   '钙奶',
#   '多美滋',
#   '雅培',
#   '美汁',
#   '源果',
#   '粒奶',
#   '优',
#   '菠萝',
#   '味',
#   '的',
#   '都',
#   '含有',
#   '肉毒',
#   '杆菌',
#   '现在',
#   '紧急',
#   '召回',
#   '希望',
#   '有',
#   '儿女',
#   '的',
#   '爸爸妈妈',
#   '相互',
#   '转告',
#   '尴尬',
#   '这个',
#   '一定',
#   '要',
#   '转',
#   '和平路'],
#  ['扶摇',
#   '镇魂',
#   '延喜',
#   '攻略',
#   '最近',
#   '的',
#   '编剧',
#   '怎么',
#   '了',
#   '扶摇',
#   '黑化',
#   '流传',
#   '要',
#   '隔壁',
#   '镇魂',
#   '延禧',
#   '宫略',
#   '皇后',
#   '要',
#   '挂',
#   '媚者',
#   '无疆',
#   '开虐',
#   '虐虐',
#   '更',
#   '开心',
#   '是',
#   '伐',
#   '是',
#   '的',
#   '哈哈哈哈',
#   '不',
#   '不',
#   '扶摇',
#   '结局',
#   '是',
#   '好像',
#   '扶摇',
#   '最后',
#   '被帝',
#   '非天',
#   '附身',
#   '黑化',
#   '了',
#   '太子',
#   '刺死',
#   '了',
#   '扶摇',
#   '吧',
#   '然后',
#   '自杀',
#   '了',
#   '延禧',
#   '攻略',
#   '傅恒',
#   '缨络'],
#  ['急',
#   '找',
#   '孩子',
#   '求转',
#   '求',
#   '帮忙',
#   '帮忙',
#   '扩散',
#   '昨天上午',
#   '一个三岁',
#   '多',
#   '小女孩',
#   '在',
#   '石家庄',
#   '荣',
#   '景园',
#   '小区',
#   '附近',
#   '被',
#   '人',
#   '拐走',
#   '了',
#   '小女孩',
#   '能',
#   '说出',
#   '她',
#   '爸爸',
#   '的',
#   '手机号码',
#   '从',
#   '监控',
#   '上',
#   '看',
#   '是',
#   '被',
#   '一个四十多岁',
#   '男人',
#   '抱',
#   '走',
#   '了',
#   '现',
#   '大人',
#   '都',
#   '急',
#   '疯',
#   '了',
#   '有',
#   '知情者',
#   '请告',
#   '之',
#   '万分',
#   '感谢',
#   '看到',
#   '信息',
#   '的',
#   '兄弟姐妹',
#   '留意',
#   '一下',
#   '联系人',
#   '张静杰',
#   '志愿者',
#   '静宇',
#   '国道',
#   '前排',
#   '好',
#   '想',
#   '去',
#   '找',
#   '你',
#   '啊',
#   '好帥',
#   '连',
#   '你',
#   '的',
#   '抬头纹',
#   '都',
#   '是',
#   '这么',
#   '的',
#   '帅气',
#   '哈哈哈哈',
#   '这特',
#   '么',
#   '迷人',
#   '的',
#   '微微',
#   '侧脸',
#   '虐',
#   '我',
#   '千百回',
#   '我',
#   '都',
#   '愿',
#   '高颜值',
#   '特工',
#   '组去',
#   '执行',
#   '任务',
#   '吗',
#   '网页',
#   '链接',
#   '斐',
#   '查兹约',
#   '车夫',
#   '海獭',
#   '老鱼',
#   '宇哥',
#   '速速',
#   '赶来',
#   '第二张',
#   '巨像',
#   '嘻嘻',
#   '這個',
#   '顏值',
#   '簡直',
#   '是',
#   '逆',
#   '生長',
#   '呀',
#   '评论',
#   '配图',
#   '山林',
#   '川泽',
#   '这',
#   '两个',
#   '流弊',
#   '我',
#   '两大',
#   '男神',
#   '同框',
#   '了',
#   '帅',
#   '我',
#   '第一次',
#   '看成',
#   '上海',
#   '白',
#   '激动',
#   '了',
#   '真的',
#   '是',
#   '你家',
#   '手表',
#   '也',
#   '瑞士',
#   '拜戈表',
#   '好帅',
#   '米奇',
#   '比心',
#   '七夜',
#   '杜兹',
#   '肺鱼',
#   '真',
#   '好看',
#   '帅',
#   '的',
#   '嘞',
#   '挤眼',
#   '佩佩',
#   '的',
#   '剪刀手',
#   '笑',
#   '笑',
#   '笑',
#   '笑',
#   '就',
#   '没有',
#   '人',
#   '夸',
#   '我',
#   '精灵',
#   '王佩佩',
#   '吗',
#   '网页',
#   '链接',
#   '太',
#   '开心',
#   '帅哥',
#   '约个',
#   '会',
#   '吗',
#   '污',
#   '笑',
#   '而',
#   '不语',
#   '颜值',
#   '吹',
#   '爆',
#   '了',
#   '坐等',
#   '新剧',
#   '剧荒',
#   '了',
#   '喜欢',
#   '你',
#   '的',
#   '第三天',
#   '莫非',
#   '是',
#   '看到',
#   '让',
#   '发自',
#   '拍',
#   '的',
#   '私信',
#   '了',
#   '巧合',
#   '巧合',
#   '黄宗泽',
#   '就',
#   '喜欢',
#   '这张',
#   '脸',
#   '花心',
#   '脸',
#   '污',
#   '污',
#   '笑',
#   '而',
#   '不语',
#   '越来越',
#   '爱',
#   '你',
#   '了',
#   '帅',
#   '的',
#   '一',
#   '逼',
#   '在',
#   '中国式',
#   '俊朗',
#   '的',
#   '身边',
#   '老外',
#   '的',
#   '颜值',
#   '显',
#   '逊色',
#   '赞',
#   '赞',
#   '快',
#   '冻死',
#   '了',
#   '其实',
#   '你',
#   '早',
#   '已经',
#   '系',
#   '我',
#   '心目',
#   '中噶视帝',
#   '了',
#   '怎么样',
#   '才能',
#   '泡到',
#   '黄宗泽',
#   '在线',
#   '等',
#   '你',
#   '最',
#   '好看',
#   '那',
#   '不是',
#   '佩佩',
#   '吗',
#   '一如既往',
#   '的',
#   '帅',
#   '俩',
#   '美',
#   '男',
#   '心',
#   '心',
#   '心'],
#  ['蔡',
#   '徐坤',
#   '蔡',
#   '徐坤',
#   '偶像',
#   '练习生',
#   '紧急',
#   '举报',
#   '有害',
#   '网页',
#   '链接',
#   '此人',
#   '顶',
#   '着',
#   '蔡',
#   '徐坤',
#   '头像',
#   '四处',
#   '招黑',
#   '反黑组',
#   '核实',
#   '后',
#   '发现',
#   '微博',
#   '也',
#   '只有',
#   '三条',
#   '蔡',
#   '徐坤',
#   '相关',
#   '所以',
#   '此人',
#   '为',
#   '披皮',
#   '黑反',
#   '黑组',
#   '说',
#   '过',
#   '顶',
#   '着',
#   '蔡',
#   '徐坤',
#   '头像',
#   '就要',
#   '专注',
#   '自家',
#   '否则',
#   '无论是',
#   '谁',
#   '按照',
#   '披皮',
#   '黑',
#   '处理',
#   '谢谢合作',
#   '无语',
#   '啊',
#   '举报',
#   '好',
#   '多次',
#   '了',
#   '无语',
#   '啊',
#   '卡',
#   '这个',
#   '批皮',
#   '黑',
#   '举报',
#   '了',
#   '多少',
#   '遍',
#   '怎么',
#   '还',
#   '在',
#   '啊啊啊',
#   '啊啊啊',
#   '是',
#   '谁家',
#   '这么',
#   '贱',
#   '好好',
#   '的',
#   '人',
#   '不',
#   '做',
#   '非要',
#   '搞',
#   '这些',
#   '小动作',
#   '啊',
#   '我',
#   '气死',
#   '了',
#   '孽',
#   '力回馈',
#   '吧',
#   '弱',
#   '弱',
#   '弱',
#   '弱',
#   '弱',
#   '弱',
#   '弱',
#   '举报',
#   '好',
#   '多次',
#   '了',
#   '这',
#   '人',
#   '有毒',
#   '吧',
#   '这个',
#   '真是',
#   '不要脸',
#   '了',
#   '当初',
#   '惹',
#   '流量',
#   '卡',
#   '已经',
#   '举报',
#   '过',
#   '看来',
#   '已经',
#   '被',
#   '挂',
#   '过',
#   '了',
#   '靠',
#   '举报',
#   '好',
#   '几次',
#   '了',
#   '卧槽',
#   '辣鸡',
#   '去死吧',
#   '怒骂',
#   '怒骂',
#   '怒骂',
#   '怒骂',
#   '卡',
#   '已经',
#   '举报',
#   '过',
#   '了',
#   '这个',
#   '披皮',
#   '黑真',
#   '不要脸',
#   '祝',
#   '你',
#   '蒸煮',
#   '糊穿',
#   '地心',
#   '卡',
#   '卡',
#   '卡',
#   '这个',
#   '举报',
#   '了',
#   '不',
#   '知道',
#   '多少',
#   '次',
#   '了',
#   '怎么',
#   '还',
#   '在',
#   '这',
#   '卡',
#   '卡',
#   '卡',
#   '这个',
#   '人',
#   '好气',
#   '啊',
#   '乱跑',
#   '别家',
#   '超话',
#   '给',
#   '我们',
#   '招黑',
#   '卡',
#   '他',
#   '就是',
#   '个',
#   '职黑',
#   '我',
#   '都',
#   '已经',
#   '拉',
#   '黑过',
#   '他',
#   '了',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡'],
#  ['朋友圈',
#   '疯传',
#   '的',
#   '雪地',
#   '老人',
#   '他',
#   '是',
#   '我',
#   '的',
#   '父亲',
#   '已',
#   '走失',
#   '七年',
#   '本报讯',
#   '记者',
#   '朱长振',
#   '文',
#   '图',
#   '一场',
#   '暴雪',
#   '过后',
#   '郑州',
#   '的',
#   '气温',
#   '直线',
#   '下降',
#   '接连',
#   '几天',
#   '来',
#   '网页',
#   '链接'],
#  ['帮',
#   '朋友',
#   '转',
#   '的',
#   '刘波',
#   '全家',
#   '跪谢',
#   '大家',
#   '了',
#   '快转',
#   '刘波',
#   '电话',
#   '今天上午',
#   '的',
#   '岁',
#   '儿子',
#   '在',
#   '成都',
#   '双语',
#   '幼儿园',
#   '附近',
#   '被',
#   '人',
#   '拐走',
#   '了',
#   '儿子',
#   '能',
#   '说出',
#   '他',
#   '妈妈',
#   '的',
#   '手机号码',
#   '从',
#   '监控',
#   '上',
#   '看',
#   '是',
#   '被',
#   '一个三十多岁',
#   '女人',
#   '抱',
#   '走',
#   '了',
#   '现',
#   '我们',
#   '家',
#   '老奶奶',
#   '都',
#   '急',
#   '疯',
#   '了',
#   '有',
#   '知情者',
#   '请告',
#   '之',
#   '万分',
#   '感谢',
#   '看到',
#   '信息',
#   '的',
#   '兄弟姐妹',
#   '留意',
#   '一下',
#   '联系人',
#   '刘波',
#   '电话',
#   '如果',
#   '看',
#   '一眼',
#   '懒得',
#   '转',
#   '的',
#   '冷漠',
#   '人',
#   '也',
#   '请',
#   '你',
#   '伸出',
#   '手指',
#   '按',
#   '秒',
#   '看到',
#   '就',
#   '转转',
#   '吧',
#   '我们',
#   '都',
#   '会',
#   '有',
#   '孩子',
#   '谢谢',
#   '你'],
#  ['瞪',
#   '瞪',
#   '我',
#   '就',
#   '现在',
#   '网页',
#   '链接',
#   '羞嗒',
#   '嗒',
#   '羞嗒',
#   '嗒',
#   '这',
#   '都',
#   '多',
#   '老',
#   '的',
#   '图',
#   '了',
#   '哈哈哈哈',
#   '哈哈哈哈',
#   '哈哈哈',
#   '我',
#   '也',
#   '瞪',
#   '网页',
#   '链接',
#   '网页',
#   '链接',
#   '喵',
#   '喵',
#   '喵',
#   '喵',
#   '喵',
#   '喵',
#   '图片',
#   '评论',
#   '网页',
#   '链接',
#   '鬼',
#   '老师',
#   '安静',
#   '连',
#   '我',
#   '都',
#   '开学',
#   '了',
#   '网页',
#   '链接',
#   '二哈',
#   '二哈',
#   '二哈',
#   '二哈',
#   '老师',
#   '你',
#   '的',
#   '手机',
#   '壳',
#   '快',
#   '拿',
#   '好',
#   '网页',
#   '链接',
#   '老师',
#   '你别',
#   '瞪',
#   '我',
#   '我',
#   '写',
#   '完',
#   '作业',
#   '了',
#   '网页',
#   '链接',
#   '今晚',
#   '湖南卫视',
#   '快乐',
#   '大本营',
#   '见',
#   '网页',
#   '链接',
#   '奥特曼',
#   '奥特曼',
#   '奥特曼',
#   '吓死',
#   '啦',
#   '吓死',
#   '啦',
#   '允悲',
#   '帅',
#   '的',
#   '啊',
#   '胡',
#   '老师',
#   '出师表',
#   '全文',
#   '背诵',
#   '一遍',
#   '很久没',
#   '看',
#   '快乐',
#   '大本营',
#   '了',
#   '今晚',
#   '蹲',
#   '你',
#   '图片',
#   '评论',
#   '网页',
#   '链接',
#   '这',
#   '更博',
#   '速度',
#   '可以',
#   '继续',
#   '保持',
#   '网页',
#   '链接',
#   '二哈',
#   '开学',
#   '啦',
#   '好',
#   '网页',
#   '链接',
#   '偷笑',
#   '同学',
#   '们',
#   '准备',
#   '好',
#   '小',
#   '板凳',
#   '了',
#   '吗',
#   '我们',
#   '的',
#   '胡',
#   '老师',
#   '开课',
#   '啦',
#   '网页',
#   '链接',
#   '哈哈',
#   '卞兄',
#   '你',
#   '红',
#   '了',
#   '连',
#   '我',
#   '三个',
#   '月',
#   '没发',
#   '一条',
#   '微博',
#   '的',
#   '人',
#   '都',
#   '长粉',
#   '了',
#   '允悲',
#   '无常',
#   '会',
#   '出成',
#   '一首歌',
#   '吗',
#   '你',
#   '今天',
#   '是',
#   '重庆',
#   '吴彦祖',
#   '本人',
#   '了',
#   '网页',
#   '链接',
#   '我',
#   '是',
#   '来自',
#   '重庆',
#   '勒似',
#   '雾都',
#   '这是',
#   '来自',
#   '红花',
#   '会',
#   '万磁王',
#   '哟',
#   '这',
#   '是',
#   '你',
#   '的',
#   '男孩',
#   '从',
#   '到',
#   '广州',
#   '我',
#   '从',
#   '货运站',
#   '到',
#   '码头',
#   '我',
#   '是',
#   '鬼',
#   '卞',
#   '来自',
#   '重庆',
#   '实验',
#   '一小'],
#  ['说',
#   '故意',
#   '杀人',
#   '的',
#   '你们',
#   '真的',
#   '有',
#   '智商',
#   '男子',
#   '东莞',
#   '被',
#   '运钞',
#   '员',
#   '枪杀案',
#   '家属',
#   '最终',
#   '获赔',
#   '万'],
#  ['金志',
#   '文',
#   '把',
#   '关关雎',
#   '鸠',
#   '唱',
#   '给',
#   '你',
#   '听',
#   '关关雎',
#   '鸠',
#   '在',
#   '河之洲',
#   '窈窕淑女',
#   '君子好逑',
#   '三千年',
#   '前',
#   '人们',
#   '用',
#   '诗词',
#   '畅言',
#   '爱意',
#   '三千年',
#   '后',
#   '金志',
#   '文与',
#   '湖北',
#   '房县',
#   '一群',
#   '普通',
#   '的',
#   '民歌',
#   '爱好者',
#   '在',
#   '田间',
#   '地头',
#   '与',
#   '千年',
#   '经典',
#   '发出',
#   '碰撞',
#   '以',
#   '最',
#   '真实',
#   '的',
#   '生命',
#   '歌唱',
#   '经久不息',
#   '的',
#   '华夏',
#   '篇章',
#   '经典',
#   '咏',
#   '金志',
#   '文',
#   '言念',
#   '君子',
#   '温其',
#   '如玉',
#   '用来',
#   '形容',
#   '经典',
#   '传唱',
#   '人',
#   '金志',
#   '文',
#   '演绎',
#   '的',
#   '关关雎',
#   '鸠',
#   '金志',
#   '文',
#   '最',
#   '贴合',
#   '不过',
#   '了',
#   '好',
#   '词曲',
#   '好',
#   '节目',
#   '经过',
#   '这么',
#   '优秀',
#   '的',
#   '经典',
#   '传唱',
#   '人',
#   '优秀',
#   '的',
#   '幕后',
#   '工作人员',
#   '的',
#   '演绎',
#   '必将',
#   '永',
#   '流传',
#   '经典',
#   '咏',
#   '流传',
#   '音乐',
#   '中国',
#   '赞',
#   '中国',
#   '赞',
#   '中国',
#   '赞',
#   '好',
#   '爱',
#   '哦',
#   '好',
#   '爱',
#   '哦',
#   '好',
#   '爱',
#   '哦',
#   '金志',
#   '文是',
#   '个',
#   '有',
#   '才华',
#   '的',
#   '段子',
#   '手',
#   '我',
#   '就',
#   '不',
#   '告诉',
#   '你',
#   '我',
#   '是',
#   '谁',
#   '啦',
#   '啦',
#   '啦',
#   '好',
#   '啊',
#   '我',
#   '等',
#   '你',
#   '唱',
#   '给',
#   '我',
#   '听',
#   '挤眼',
#   '微风',
#   '心',
#   '金志',
#   '文',
#   '言念',
#   '君子',
#   '温其',
#   '如玉',
#   '用来',
#   '形容',
#   '经典',
#   '传唱',
#   '人',
#   '金志',
#   '文',
#   '演绎',
#   '的',
#   '关关雎',
#   '鸠',
#   '金志',
#   '文',
#   '最',
#   '贴合',
#   '不过',
#   '了',
#   '好',
#   '词曲',
#   '好',
#   '节目',
#   '经过',
#   '这么',
#   '优秀',
#   '的',
#   '经典',
#   '传唱',
#   '人',
#   '优秀',
#   '的',
#   '幕后',
#   '工作人员',
#   '的',
#   '演绎',
#   '必将',
#   '永',
#   '流传',
#   '经典',
#   '咏',
#   '流传',
#   '音乐',
#   '中国',
#   '赞',
#   '中国',
#   '赞',
#   '中国',
#   '赞',
#   '好',
#   '爱',
#   '哦',
#   '好',
#   '爱',
#   '哦',
#   '好',
#   '爱',
#   '哦',
#   '好',
#   '美的',
#   '声音',
#   '寻味',
#   '诗情画意',
#   '好听',
#   '乐队',
#   '也',
#   '很',
#   '赞',
#   '中国',
#   '风',
#   '中国',
#   '赞',
#   '中国',
#   '赞',
#   '好好',
#   '听',
#   '好帅',
#   '啊',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '爱',
#   '你',
#   '金志',
#   '文',
#   '唱歌',
#   '真不错',
#   '把',
#   '诗经',
#   '唱活',
#   '了',
#   '水平',
#   '如何',
#   '金志',
#   '文',
#   '关关雎',
#   '鸠',
#   '金志',
#   '文',
#   '音乐'],
#  ['中国',
#   '养猪',
#   '出现',
#   '猪瘟',
#   '疫情',
#   '为啥',
#   '还要',
#   '往',
#   '非洲',
#   '那么',
#   '遥远',
#   '的',
#   '地方',
#   '绕个',
#   '弯',
#   '史书',
#   '记载',
#   '世间',
#   '万物',
#   '都',
#   '发生',
#   '过',
#   '疫情',
#   '非典',
#   '是',
#   '人类',
#   '疫情',
#   '难道说',
#   '是',
#   '非洲',
#   '蚊子',
#   '协',
#   '带病毒',
#   '传染',
#   '的',
#   '吗',
#   '环保部门',
#   '什么',
#   '时候',
#   '有空',
#   '关心',
#   '一下',
#   '养猪户',
#   '不',
#   '规范',
#   '的',
#   '养殖场',
#   '约束',
#   '一下',
#   '卫生防疫',
#   '站',
#   '多',
#   '给',
#   '养殖户',
#   '提供',
#   '点',
#   '预防',
#   '知识',
#   '这些',
#   '疫情',
#   '还',
#   '能',
#   '发生',
#   '吗'],
#  ['最近',
#   '不太敢',
#   '发说',
#   '说',
#   '整个',
#   '朋友圈',
#   '弥漫',
#   '当下',
#   '你',
#   '还',
#   '发自',
#   '拍',
#   '丝毫',
#   '没有',
#   '基本',
#   '的',
#   '民族',
#   '责任感',
#   '最近',
#   '微博',
#   '的',
#   '舆论',
#   '走向',
#   '特别',
#   '奇怪',
#   '每件事',
#   '才',
#   '出来',
#   '都',
#   '不敢',
#   '跟',
#   '热点',
#   '事实',
#   '也',
#   '证明',
#   '这种',
#   '时候',
#   '最先',
#   '被',
#   '煽动',
#   '的',
#   '朋友',
#   '们',
#   '最后',
#   '会',
#   '被',
#   '打',
#   '脸',
#   '朋友',
#   '说',
#   '的',
#   '谣言',
#   '会',
#   '驱使',
#   '大众',
#   '挖',
#   '根究',
#   '底',
#   '认同',
#   '不',
#   '反对',
#   '民族',
#   '愤青',
#   '们',
#   '可不',
#   '跟风',
#   '不',
#   '说明',
#   '不',
#   '关注'],
#  ['群内',
#   '与',
#   '人',
#   '相约',
#   '跳崖',
#   '自杀',
#   '泉州',
#   '小伙',
#   '被',
#   '女网友',
#   '救',
#   '下',
#   '从',
#   '泉州',
#   '匆匆',
#   '赶来',
#   '的',
#   '黄先生',
#   '终于',
#   '见到',
#   '了',
#   '三年',
#   '未见',
#   '的',
#   '儿子',
#   '阿水',
#   '化名',
#   '阿水',
#   '原本',
#   '与',
#   '女网友',
#   '相约',
#   '去',
#   '峨眉山',
#   '跳崖',
#   '被',
#   '警方',
#   '拦下',
#   '而',
#   '女网友',
#   '其实',
#   '为',
#   '湖南',
#   '一',
#   '父亲',
#   '假扮',
#   '他',
#   '救',
#   '下',
#   '了',
#   '别人',
#   '的',
#   '孩子'],
#  ['四川',
#   '广安',
#   '武胜县',
#   '城南',
#   '今天',
#   '抢',
#   '小孩',
#   '没',
#   '抢走',
#   '把',
#   '孩子',
#   '母亲',
#   '捅',
#   '了',
#   '一刀',
#   '看见',
#   '这车',
#   '的',
#   '注意',
#   '了',
#   '真',
#   '事',
#   '车牌号',
#   '冀',
#   '赶紧',
#   '散播',
#   '都',
#   '别带',
#   '孩子',
#   '出去',
#   '瞎',
#   '转悠',
#   '了',
#   '尤其',
#   '别',
#   '让',
#   '老人',
#   '自己',
#   '带',
#   '孩子',
#   '出去',
#   '太',
#   '危险',
#   '了',
#   '注意',
#   '了',
#   '晋',
#   '五菱',
#   '面包车',
#   '在',
#   '各',
#   '学校',
#   '门口',
#   '抢',
#   '小孩',
#   '已经',
#   '证实',
#   '全市',
#   '通缉',
#   '啊',
#   '又',
#   '发生',
#   '这种',
#   '事情',
#   '了',
#   '回复',
#   '静雪',
#   '咚咚',
#   '太',
#   '恐怖',
#   '了',
#   '坏人',
#   '太',
#   '猖獗'],
#  ['急转',
#   '急',
#   '找',
#   '孩子',
#   '求转',
#   '求',
#   '帮忙',
#   '寿光',
#   '实验',
#   '小学',
#   '寻人启事',
#   '帮忙',
#   '扩散',
#   '今天上午',
#   '一个三岁',
#   '多',
#   '小女孩',
#   '在',
#   '寿光',
#   '蔬菜',
#   '博览会',
#   '现场',
#   '被',
#   '人',
#   '拐走',
#   '了',
#   '小女孩',
#   '能',
#   '说出',
#   '她',
#   '爸爸',
#   '的',
#   '手机号码',
#   '从',
#   '监控',
#   '上',
#   '看',
#   '是',
#   '被',
#   '一个四十多岁',
#   '男人',
#   '抱',
#   '走',
#   '了',
#   '现',
#   '大人',
#   '都',
#   '急',
#   '疯',
#   '了',
#   '有',
#   '知情者',
#   '请告',
#   '之',
#   '万分',
#   '感谢',
#   '联系人',
#   '张静杰',
#   '急',
#   '找',
#   '孩子',
#   '求转',
#   '求',
#   '帮忙',
#   '实验',
#   '小学',
#   '寻人启事',
#   '帮忙',
#   '扩散',
#   '今天上午',
#   '一个三岁',
#   '多',
#   '小女孩',
#   '在',
#   '蔬菜',
#   '博览会',
#   '现场',
#   '被',
#   '人',
#   '拐走',
#   '了',
#   '小女孩',
#   '能',
#   '说出',
#   '她',
#   '爸爸',
#   '的',
#   '手机号码',
#   '从',
#   '监控',
#   '上',
#   '看',
#   '是',
#   '被',
#   '一个四十多岁',
#   '男人',
#   '抱',
#   '走',
#   '了',
#   '现',
#   '大人',
#   '都',
#   '急',
#   '疯',
#   '了',
#   '有',
#   '知情者',
#   '请告',
#   '之',
#   '万分',
#   '感谢',
#   '看到',
#   '信息',
#   '的',
#   '兄弟姐妹',
#   '留意',
#   '一下',
#   '联系人',
#   '张静杰',
#   '假',
#   '的',
#   '回复',
#   '嬉笑怒骂',
#   '网',
#   '你',
#   '怎么',
#   '知道',
#   '你',
#   '受骗上当',
#   '了',
#   '这是',
#   '虚假',
#   '消息',
#   '请',
#   '看',
#   '辟谣',
#   '网址',
#   '谣场',
#   '现形记',
#   '尽快',
#   '删除',
#   '帖子',
#   '因为',
#   '已',
#   '被',
#   '举报',
#   '回复',
#   '土',
#   '卡拉',
#   '农产品',
#   '张静杰',
#   '丢',
#   '了',
#   '无数个',
#   '孩子',
#   '了',
#   '人人',
#   '都',
#   '知道',
#   '就',
#   '你们',
#   '这些',
#   '爱心',
#   '泛滥',
#   '的',
#   '人',
#   '还',
#   '在',
#   '转发'],
#  ['地震',
#   '来',
#   '了',
#   '该',
#   '如何',
#   '科学',
#   '自救',
#   '中国',
#   '地震',
#   '网',
#   '正式',
#   '测定',
#   '月',
#   '日',
#   '时',
#   '分',
#   '在',
#   '新疆',
#   '乌鲁木齐市',
#   '乌鲁木齐县',
#   '北纬',
#   '度',
#   '东经',
#   '度',
#   '发生',
#   '级',
#   '地震',
#   '震源',
#   '深度',
#   '千米',
#   '地震',
#   '来',
#   '了',
#   '该',
#   '如何',
#   '科学',
#   '自救'],
#  ['儿童',
#   '伤害',
#   '曝光',
#   '台',
#   '游乐',
#   '设施',
#   '故障',
#   '女孩',
#   '被',
#   '甩',
#   '身亡',
#   '月',
#   '日',
#   '下午',
#   '记者',
#   '从',
#   '丰都',
#   '县委',
#   '宣传部',
#   '获悉',
#   '该县',
#   '朝华',
#   '公园',
#   '游乐',
#   '设施',
#   '遨游太空',
#   '出现',
#   '故障',
#   '导致',
#   '一名',
#   '岁',
#   '女孩',
#   '被',
#   '甩出',
#   '后',
#   '抢救无效',
#   '身亡',
#   '游乐',
#   '设施',
#   '发',
#   '太',
#   '吓人',
#   '了',
#   '昨天',
#   '还',
#   '巴巴',
#   '得',
#   '想',
#   '玩',
#   '这个',
#   '呢',
#   '但是',
#   '看',
#   '了',
#   '别人',
#   '玩',
#   '觉得',
#   '好',
#   '吓人',
#   '就',
#   '没',
#   '玩'],
#  ['我',
#   '总以为',
#   '和尚',
#   '打架',
#   '要',
#   '用',
#   '少林功夫',
#   '呢',
#   '没想到',
#   '很',
#   '普通人',
#   '一样',
#   '也',
#   '是',
#   '拳打脚踢',
#   '呀',
#   '扬州',
#   '宁国',
#   '寺',
#   '名',
#   '和尚',
#   '打架',
#   '住持',
#   '发',
#   '朋友圈',
#   '全',
#   '开除'],
#  ['永远',
#   '不要',
#   '从',
#   '别人',
#   '口中',
#   '去',
#   '了解',
#   '另',
#   '一个',
#   '人',
#   '有时候',
#   '我们',
#   '眼睛',
#   '看到',
#   '的',
#   '也',
#   '只不过',
#   '是',
#   '冰山一角',
#   '还',
#   '只是',
#   '自己',
#   '想',
#   '看到',
#   '的',
#   '那',
#   '一角',
#   '罢了',
#   '如果',
#   '透过',
#   '这',
#   '一个',
#   '小角',
#   '对',
#   '整座',
#   '冰山',
#   '下',
#   '定论',
#   '实在',
#   '是',
#   '太',
#   '不',
#   '成熟',
#   '的',
#   '做法',
#   '了',
#   '你',
#   '又',
#   '不是',
#   '他',
#   '怎',
#   '会',
#   '知道',
#   '他',
#   '经历',
#   '过',
#   '什么',
#   '有着',
#   '怎样',
#   '的',
#   '伤口',
#   '你',
#   '只',
#   '看到',
#   '舍友',
#   '小气',
#   '却',
#   '没',
#   '看到',
#   '他',
#   '为了',
#   '赚',
#   '块钱',
#   '一',
#   '小时',
#   '的',
#   '薪水',
#   '用',
#   '别人',
#   '打游戏',
#   '的',
#   '时间',
#   '在',
#   '学校食堂',
#   '勤工俭学',
#   '收拾',
#   '别人',
#   '的',
#   '剩菜',
#   '剩饭',
#   '你',
#   '只',
#   '看到',
#   '那个',
#   '女生',
#   '不',
#   '搭理',
#   '人',
#   '不愿',
#   '敞开',
#   '心扉',
#   '却',
#   '没',
#   '看到',
#   '她',
#   '中学',
#   '时',
#   '曾',
#   '被',
#   '最好',
#   '的',
#   '朋友',
#   '背叛',
#   '让',
#   '她',
#   '在',
#   '学校',
#   '里',
#   '遭受',
#   '了',
#   '周围',
#   '同学',
#   '怎样',
#   '的',
#   '非议',
#   '可是',
#   '生活',
#   '中',
#   '总',
#   '有人',
#   '自信',
#   '地',
#   '以为',
#   '自己',
#   '看到',
#   '的',
#   '就是',
#   '这个',
#   '世界',
#   '的',
#   '全貌',
#   '他们',
#   '用',
#   '自己',
#   '的',
#   '标准',
#   '衡量',
#   '着',
#   '所有',
#   '一切',
#   '轻易',
#   '对',
#   '他人',
#   '做出',
#   '的',
#   '事情',
#   '品头论足',
#   '若',
#   '是',
#   '将',
#   '加入',
#   '了',
#   '自己',
#   '主观',
#   '臆想',
#   '的',
#   '结论',
#   '当成',
#   '客观事实',
#   '来',
#   '传播',
#   '更会',
#   '在',
#   '不知不觉',
#   '中',
#   '伤害',
#   '无辜',
#   '的',
#   '人',
#   '就',
#   '像',
#   '之前',
#   '一部',
#   '电影',
#   '里',
#   '刚刚',
#   '查出',
#   '癌症',
#   '晚期',
#   '的',
#   '女主角',
#   '因在',
#   '公交车',
#   '上',
#   '没有',
#   '给',
#   '老人',
#   '让座',
#   '就',
#   '成',
#   '了',
#   '全民',
#   '唾弃',
#   '的',
#   '对象',
#   '人们',
#   '一味',
#   '的',
#   '指责',
#   '着',
#   '她',
#   '的',
#   '冷漠',
#   '无情',
#   '却',
#   '没',
#   '看到',
#   '她',
#   '身上',
#   '的',
#   '千疮百孔',
#   '不知',
#   '什么',
#   '时候',
#   '起',
#   '道听途说',
#   '成',
#   '了',
#   '一件',
#   '特别',
#   '正常',
#   '的',
#   '事',
#   '不管',
#   '是',
#   '传播者',
#   '还是',
#   '打探',
#   '者',
#   '都',
#   '特别',
#   '理直气壮',
#   '可',
#   '你',
#   '有没有',
#   '想过',
#   '你',
#   '对',
#   '他人',
#   '的',
#   '判断',
#   '有',
#   '多少',
#   '是',
#   '有',
#   '证据',
#   '依托',
#   '的',
#   '又',
#   '有',
#   '多少',
#   '是',
#   '凭',
#   '自己',
#   '的',
#   '猜测',
#   '脑补',
#   '的',
#   '谁',
#   '敢',
#   '保证',
#   '自己',
#   '说出',
#   '的',
#   '听到',
#   '的',
#   '一定',
#   '是',
#   '真相',
#   '而',
#   '不是',
#   '歪曲',
#   '了',
#   '事实',
#   '的',
#   '谣言',
#   '呢',
#   '而',
#   '这些',
#   '来历不明',
#   '的',
#   '话语',
#   '常常',
#   '对',
#   '我们',
#   '形成',
#   '一个',
#   '引导',
#   '很大',
#   '程度',
#   '上',
#   '先入为主',
#   '地',
#   '影响',
#   '我们',
#   '的',
#   '判断',
#   '特别',
#   '是',
#   '当',
#   '我们',
#   '对',
#   '某件事',
#   '物有',
#   '不好',
#   '的',
#   '印象',
#   '时',
#   '它',
#   '就',
#   '很',
#   '可能',
#   '往',
#   '不好',
#   '的',
#   '方向',
#   '发展',
#   '傲慢',
#   '与',
#   '偏见',
#   '里',
#   '有',
#   '一句',
#   '话',
#   '傲慢',
#   '让',
#   '别人',
#   '无法',
#   '来',
#   '爱',
#   '我',
#   '偏见',
#   '让',
#   '我',
#   '无法',
#   '去',
#   '爱',
#   '别人',
#   '对待',
#   '他人',
#   '他物',
#   '的',
#   '偏见',
#   '时时刻刻',
#   '潜伏',
#   '在',
#   '我们',
#   '的',
#   '脑海中',
#   '影响',
#   '着',
#   '我们',
#   '的',
#   '选择',
#   '别人',
#   '说',
#   '某',
#   '品牌',
#   '包包',
#   '不好',
#   '用',
#   '根本',
#   '不值',
#   '这个',
#   '价',
#   '你',
#   '就',
#   '对',
#   '这个',
#   '品牌',
#   '没什么',
#   '好',
#   '印象',
#   '从来不',
#   '会',
#   '购买',
#   '别人',
#   '说',
#   '某',
#   '女星',
#   '靠',
#   '潜规则',
#   '上位',
#   '你',
#   '就',
#   '觉得',
#   '她',
#   '没有',
#   '真才实学',
#   '怎么',
#   '看',
#   '怎么',
#   '是',
#   '靠',
#   '脸',
#   '吃饭',
#   '的',
#   '类型',
#   '于是',
#   '不再',
#   '看',
#   '她',
#   '的',
#   '节目',
#   '别人',
#   '说',
#   '某',
#   '同学',
#   '人品',
#   '很差',
#   '你',
#   '就',
#   '越',
#   '看',
#   '她',
#   '越',
#   '不',
#   '顺眼',
#   '生活',
#   '中',
#   '避免',
#   '和',
#   '她',
#   '接触',
#   '于是',
#   '你们',
#   '越来越',
#   '生疏',
#   '很多',
#   '人',
#   '都',
#   '是',
#   '这样',
#   '容易',
#   '被',
#   '他人',
#   '的',
#   '话语',
#   '左右',
#   '自己',
#   '的',
#   '判断',
#   '但',
#   '从',
#   '别人',
#   '口中',
#   '说出',
#   '的话',
#   '实际上',
#   '都',
#   '是',
#   '他',
#   '的',
#   '观点',
#   '而',
#   '非',
#   '事实',
#   '一个',
#   '真正',
#   '成熟',
#   '的',
#   '人',
#   '又',
#   '怎么',
#   '会',
#   '轻易',
#   '相信',
#   '别人',
#   '的',
#   '一面之词',
#   '呢',
#   '他会用',
#   '自己',
#   '的',
#   '眼睛',
#   '去',
#   '看',
#   '用',
#   '自己',
#   '的',
#   '内心',
#   '去',
#   '感受',
#   '别人',
#   '说',
#   '某',
#   '品牌',
#   '包包',
#   '不好',
#   '用',
#   '但',
#   '你',
#   '只有',
#   '自己',
#   '背过',
#   '才',
#   '知道',
#   '原来',
#   '这个',
#   '牌子',
#   '的',
#   '包包',
#   '质量',
#   '很',
#   '好',
#   '只是',
#   '有点',
#   '贵',
#   '买',
#   '一件',
#   '能',
#   '用',
#   '年',
#   '别人',
#   '说',
#   '某',
#   '女星',
#   '没',
#   '实力',
#   '但',
#   '你',
#   '去',
#   '看过',
#   '她',
#   '的',
#   '作品',
#   '才',
#   '知道',
#   '人家',
#   '不仅',
#   '有',
#   '颜值',
#   '还',
#   '肯吃苦',
#   '是',
#   '你',
#   '应该',
#   '学习',
#   '的',
#   '榜样',
#   '别人',
#   '说',
#   '某',
#   '同学',
#   '人品',
#   '有',
#   '问题',
#   '但',
#   '你',
#   '去',
#   '和',
#   '她',
#   '交往',
#   '才',
#   '知道',
#   '她',
#   '其实',
#   '很',
#   '热心肠',
#   '还有',
#   '很多',
#   '闪光点',
#   '你们',
#   '成为',
#   '了',
#   '彼此',
#   '勉励',
#   '的',
#   '知己',
#   '你',
#   '不',
#   '知道',
#   '别人',
#   '和',
#   '你',
#   '的',
#   '立场',
#   '究竟',
#   '有',
#   '多',
#   '大',
#   '不同',
#   '也',
#   '不',
#   '知道',
#   '别人',
#   '出于',
#   '什么',
#   '目的',
#   '会',
#   '在',
#   '何时',
#   '对',
#   '自己',
#   '不',
#   '喜欢',
#   '的',
#   '人和事',
#   '进行',
#   '诽谤',
#   '但',
#   '一个',
#   '对',
#   '自己',
#   '负责',
#   '的',
#   '人',
#   '怎',
#   '会',
#   '因为',
#   '他人',
#   '的',
#   '一句',
#   '评价',
#   '错过',
#   '了',
#   '本该',
#   '属于',
#   '自己',
#   '的',
#   '美好',
#   '呢',
#   '想',
#   '了解',
#   '一个',
#   '人',
#   '一件',
#   '事',
#   '就要',
#   '用',
#   '自己',
#   '的',
#   '眼睛',
#   '去',
#   '看',
#   '用',
#   '自己',
#   '的',
#   '耳朵',
#   '去',
#   '听',
#   '用',
#   '自己',
#   '的',
#   '心',
#   '切切实实',
#   '地去',
#   '感受',
#   '也',
#   '就是',
#   '遵从',
#   '自己',
#   '的',
#   '内心',
#   '话',
#   '是',
#   '别人',
#   '说',
#   '的',
#   '但',
#   '生活',
#   '是',
#   '自己',
#   '的',
#   '我们',
#   '无法',
#   '决定',
#   '别人',
#   '对',
#   '我们',
#   '说',
#   '什么',
#   '但',
#   '可以',
#   '不',
#   '被',
#   '他们',
#   '的',
#   '评论',
#   '左右',
#   '通过',
#   '自己',
#   '的',
#   '实际',
#   '体会',
#   '去',
#   '判断',
#   '一个',
#   '东西',
#   '值不值得',
#   '买',
#   '一个',
#   '人',
#   '值不值得',
#   '交往',
#   '还是',
#   '要',
#   '自己',
#   '拿主意',
#   '我们',
#   '也',
#   '无法',
#   '阻止',
#   '别人',
#   '说',
#   '我们',
#   '的',
#   '闲话',
#   '但',
#   '可以',
#   '置之不理',
#   '坚持',
#   '做',
#   '真实',
#   '的',
#   '自己',
#   '成熟',
#   '的',
#   '人',
#   '是',
#   '不会',
#   '因',
#   '他人',
#   '的',
#   '三言两语',
#   '动摇',
#   '的',
#   '假如',
#   '有人',
#   '上',
#   '了',
#   '谣言',
#   '的',
#   '当',
#   '误解',
#   '了',
#   '我们',
#   '那',
#   '就',
#   '当作',
#   '过滤',
#   '掉',
#   '一个',
#   '不',
#   '值得',
#   '深交',
#   '的',
#   '人',
#   '吧',
#   '要',
#   '相信',
#   '路遥知马力',
#   '日久见人心',
#   '懂',
#   '你',
#   '的',
#   '人',
#   '自会',
#   '看到',
#   '你',
#   '身上',
#   '的',
#   '阳光',
#   '真正',
#   '的',
#   '朋友',
#   '会',
#   '穿过',
#   '一切',
#   '流言蜚语',
#   '跑',
#   '来',
#   '拥抱',
#   '你',
#   '作者',
#   '安安',
#   '本文',
#   '来源',
#   '七言',
#   '先生',
#   '了解',
#   '自己',
#   '都',
#   '难',
#   '不要',
#   '做',
#   '背后',
#   '说',
#   '别人',
#   '的',
#   '人',
#   '人云亦云',
#   '是',
#   '一种',
#   '催眠',
#   '也',
#   '是',
#   '人',
#   '的',
#   '共性',
#   '你',
#   '永远',
#   '不',
#   '知道',
#   '在',
#   '别人',
#   '嘴中',
#   '的',
#   '你',
#   '会',
#   '有',
#   '多少',
#   '版本',
#   '也',
#   '不会',
#   '知道',
#   '别人',
#   '为了',
#   '维护',
#   '自己',
#   '而',
#   '说',
#   '过',
#   '什么',
#   '去',
#   '诋毁',
#   '你',
#   '更',
#   '无法',
#   '阻止',
#   '那些',
#   '不切实际',
#   '的',
#   '闲话',
#   '一个',
#   '人有',
#   '很多',
#   '面都',
#   '是',
#   '给',
#   '应该',
#   '展示',
#   '的',
#   '人',
#   '看着',
#   '有时候',
#   '你',
#   '了解',
#   '过后',
#   '果真如此',
#   '太有',
#   '感触',
#   '被',
#   '人',
#   '说',
#   '不',
#   '正常',
#   '被',
#   '人',
#   '品头论足',
#   '只',
#   '了解',
#   '一面',
#   '就',
#   '感觉',
#   '了解',
#   '全部',
#   '太',
#   '自以为是',
#   '谁',
#   '都',
#   '有',
#   '缺点',
#   '只',
#   '看到',
#   '别人',
#   '缺点',
#   '而',
#   '不',
#   '去',
#   '找',
#   '自己',
#   '缺点',
#   '得知',
#   '此事',
#   '要',
#   '躬行',
#   '心',
#   '最',
#   '可怕',
#   '我',
#   '的',
#   '是',
#   '眼神',
#   '差',
#   '还',
#   '自',
#   '以为',
#   '看破',
#   '一切',
#   '的',
#   '人',
#   '眼睛',
#   '看到',
#   '的',
#   '是',
#   '事实',
#   '但',
#   '不',
#   '一定',
#   '是',
#   '真实',
#   '我',
#   '不',
#   '喜欢',
#   '从',
#   '别人',
#   '的',
#   '口中',
#   '去',
#   '了解',
#   '一个',
#   '人',
#   '因为',
#   '他',
#   '没有',
#   '那样',
#   '对',
#   '你',
#   '没',
#   '人',
#   '在乎',
#   '你',
#   '怎样',
#   '在',
#   '深夜',
#   '痛哭',
#   '也',
#   '没人',
#   '在乎',
#   '你',
#   '辗转反侧',
#   '的',
#   '要',
#   '熬',
#   '几个',
#   '秋',
#   '外人',
#   '只',
#   '看',
#   '结果',
#   '自己',
#   '独撑',
#   '过程',
#   '等',
#   '我们',
#   '都',
#   '明白',
#   '了',
#   '这个',
#   '道理',
#   '便',
#   '不会',
#   '再',
#   '在',
#   '人前',
#   '矫情',
#   '四处',
#   '诉说',
#   '以求',
#   '宽慰',
#   '喜欢',
#   '文字',
#   '的',
#   '你',
#   '可以',
#   '关',
#   '住',
#   '我',
#   '愿',
#   '我',
#   '有幸',
#   '陪',
#   '你',
#   '度过',
#   '那',
#   '难熬',
#   '的',
#   '日子',
#   '人',
#   ...],
#  ['求',
#   '扩散',
#   '今天上午',
#   '一个三岁',
#   '多',
#   '小女孩',
#   '在',
#   '德州',
#   '银座',
#   '超市',
#   '门口',
#   '被',
#   '人',
#   '拐走',
#   '了',
#   '小女孩',
#   '能',
#   '准确',
#   '说出',
#   '她',
#   '爸爸',
#   '的',
#   '手机号码',
#   '从',
#   '监控',
#   '上',
#   '看',
#   '是',
#   '被',
#   '一个四十多岁',
#   '男人',
#   '抱',
#   '走',
#   '了',
#   '现',
#   '大人',
#   '都',
#   '急',
#   '疯',
#   '了',
#   '有',
#   '知情者',
#   '请告',
#   '之',
#   '万分',
#   '感谢',
#   '看到',
#   '信息',
#   '的',
#   '兄弟姐妹',
#   '留意',
#   '一下',
#   '联系人',
#   '靳',
#   '连胜',
#   '电话',
#   '朋友',
#   '处',
#   '看到',
#   '的',
#   '应该',
#   '是',
#   '真的',
#   '看到',
#   '的',
#   '请',
#   '帮忙',
#   '在',
#   '周前',
#   '看见',
#   '过',
#   '这个',
#   '完整',
#   '的',
#   '段子',
#   '但',
#   '好像',
#   '不是',
#   '德州',
#   '转发',
#   '微博'],
#  ['内蒙古',
#   '林西县',
#   '一对',
#   '公职',
#   '夫妻',
#   '殴打',
#   '母亲',
#   '被',
#   '停职',
#   '调查',
#   '近日',
#   '一网',
#   '传',
#   '监控',
#   '视频',
#   '流传',
#   '林西县',
#   '兴安',
#   '花园',
#   '一对',
#   '夫妻',
#   '殴打',
#   '一位',
#   '老人',
#   '当地',
#   '居民',
#   '表示',
#   '被',
#   '打',
#   '老人',
#   '是',
#   '男子',
#   '的',
#   '母亲',
#   '当地',
#   '工作人员',
#   '表示',
#   '打人',
#   '的',
#   '夫妻',
#   '确实',
#   '是',
#   '当地',
#   '公务员',
#   '此事',
#   '系',
#   '家庭',
#   '纠纷',
#   '目前',
#   '夫妻',
#   '二人',
#   '均',
#   '已',
#   '被',
#   '停职',
#   '正',
#   '接受',
#   '调查',
#   '澎湃',
#   '怒',
#   '怒',
#   '怒',
#   '停',
#   '的',
#   '好',
#   '该',
#   '开除',
#   '不',
#   '解释',
#   '打人',
#   '已经',
#   '不',
#   '对',
#   '打',
#   '老人',
#   '更加',
#   '不',
#   '对',
#   '打',
#   '自己',
#   '的',
#   '母亲',
#   '而且',
#   '是',
#   '在',
#   '公众',
#   '场合',
#   '又',
#   '是',
#   '公务员',
#   '你们',
#   '是',
#   '共产党员',
#   '吗',
#   '你们',
#   '怎么',
#   '进',
#   '的',
#   '公务员',
#   '队伍',
#   '谁',
#   '是',
#   '你们',
#   '的',
#   '入党',
#   '介绍',
#   '人',
#   '我',
#   '相信',
#   '这',
#   '介绍',
#   '人',
#   '也',
#   '和',
#   '你们',
#   '一样',
#   '禽兽不如',
#   '禽兽',
#   '啊',
#   '还',
#   '对生',
#   '自己',
#   '养',
#   '自己',
#   '的',
#   '母亲',
#   '动手',
#   '会',
#   '遭天',
#   '谴',
#   '此等',
#   '不肖子孙',
#   '老衲',
#   '渡劫',
#   '之',
#   '时',
#   '绝对',
#   '引',
#   '雷劈',
#   '死',
#   '你',
#   '怒',
#   '不管',
#   '因为',
#   '什么',
#   '天大',
#   '的',
#   '理由',
#   '也',
#   '不是',
#   '你',
#   '打',
#   '父母',
#   '的',
#   '借口',
#   '天下',
#   '无不',
#   '事',
#   '的',
#   '父母',
#   '如果',
#   '真是',
#   '母亲',
#   '错',
#   '了',
#   '也',
#   '不',
#   '应该',
#   '是',
#   '拳脚相加',
#   '难道',
#   '你',
#   '不',
#   '老',
#   '了',
#   '吗',
#   '殴打',
#   '亲娘',
#   '丧尽天良',
#   '老婆',
#   '似虎',
#   '老公',
#   '如狼',
#   '养儿防老',
#   '实在',
#   '荒唐',
#   '这世',
#   '罪孽',
#   '下世',
#   '必偿',
#   '这种',
#   '人',
#   '就',
#   '不该',
#   '被生',
#   '出来',
#   '把',
#   '老',
#   '母亲',
#   '摔倒',
#   '在',
#   '地',
#   '还',
#   '不',
#   '忘',
#   '踢',
#   '两脚',
#   '厉害',
#   '啊',
#   '我',
#   '艹',
#   '网友',
#   '们',
#   '去',
#   '打',
#   '他',
#   '禽兽不如',
#   '的',
#   '东西',
#   '畜牲',
#   '二字',
#   '都',
#   '配不上',
#   '党教',
#   '你',
#   '怎么',
#   '殴打',
#   '自己',
#   '母亲',
#   '禽兽不如',
#   '此人',
#   '不除',
#   '有辱党',
#   '夫妻',
#   '已',
#   '被',
#   '开除公职',
#   '了',
#   '譱',
#   '彧',
#   '哼',
#   '能',
#   '动手',
#   '打',
#   '自己',
#   '爸妈',
#   '的',
#   '人',
#   '我',
#   '完全',
#   '不能',
#   '理解',
#   '又',
#   '不是',
#   '有',
#   '什么',
#   '深仇大恨',
#   '能',
#   '动手',
#   '打',
#   '自己',
#   '父母',
#   '的',
#   '人',
#   '就是',
#   '垃圾',
#   '如果',
#   '父母',
#   '做',
#   '了',
#   '很',
#   '过分',
#   '的',
#   '事',
#   '训斥',
#   '或者',
#   '不理',
#   '就是',
#   '了',
#   '对',
#   '老人',
#   '孩子',
#   '的',
#   '人',
#   '动手',
#   '你',
#   '是',
#   '多',
#   '没本事',
#   '有些',
#   '人',
#   '就',
#   '不该',
#   '被生',
#   '下来',
#   '夫妻',
#   '殴打',
#   '老母',
#   '和',
#   '是不是',
#   '公职',
#   '有',
#   '什么',
#   '关系',
#   '不要',
#   '总是',
#   '想',
#   '搞',
#   '得',
#   '大',
#   '新闻',
#   '公务员',
#   '不',
#   '一定',
#   '是',
#   '党员',
#   '这',
#   '就是',
#   '层层',
#   '考试',
#   '层层',
#   '选拔',
#   '出来',
#   '的',
#   '人民公仆',
#   '下手',
#   '也',
#   '忒',
#   '狠',
#   '了',
#   '点',
#   '吧',
#   '什么',
#   '人',
#   '这',
#   '是',
#   '我',
#   '当地',
#   '一个',
#   '混混',
#   '十分',
#   '凶恶',
#   '经常',
#   '一言不合',
#   '就',
#   '打人',
#   '却',
#   '唯独',
#   '怕',
#   '他',
#   '十分',
#   '瘦弱',
#   '的',
#   '母亲',
#   '呵呵',
#   '连',
#   '个',
#   '混混',
#   '都',
#   '不如',
#   '这种',
#   '垃圾',
#   '为什么',
#   '还活',
#   '得',
#   '好好',
#   '的',
#   '呢',
#   '让',
#   '他们',
#   '失业',
#   '饿死',
#   '算了',
#   '养儿',
#   '能',
#   '防老',
#   '吗',
#   '伤心',
#   '伤心',
#   '伤心',
#   '怎么',
#   '说',
#   '啦',
#   '不管',
#   '什么',
#   '理由',
#   '只要',
#   '动手',
#   '打',
#   '了',
#   '自己',
#   '母亲',
#   '就是',
#   '不',
#   '对',
#   '羊',
#   '还有',
#   '跪乳',
#   '呢',
#   '唉',
#   '應該',
#   '死',
#   '而',
#   '不是',
#   '停職',
#   '你',
#   '厉害',
#   '自己',
#   '母亲',
#   '都',
#   '能',
#   '下去',
#   '手',
#   '厉害',
#   '没有',
#   '语言',
#   '能',
#   '形容',
#   '你',
#   '了',
#   '怕',
#   '你',
#   '侮辱',
#   '了',
#   '那些',
#   '字',
#   '为什么',
#   '要',
#   '打',
#   '自己',
#   '妈',
#   '呢',
#   '唉',
#   '还是',
#   '公务员',
#   '国家',
#   '养',
#   '两条',
#   '狗',
#   '都',
#   '比',
#   '你们',
#   '强',
#   '怒骂',
#   '鄙视',
#   '打脸',
#   '怒',
#   '直接',
#   '枪毙',
#   '对',
#   '自己',
#   '母亲',
#   '这样',
#   '想想',
#   '得',
#   '多',
#   '狠毒',
#   '人',
#   '肉',
#   '真是',
#   '娶',
#   '了',
#   '媳妇',
#   '忘',
#   '了',
#   '娘',
#   '喵',
#   '喵',
#   '有话',
#   '好好',
#   '说',
#   '老人',
#   '给',
#   '看',
#   '孩子',
#   '又',
#   '不是',
#   '义务',
#   '不',
#   '知道',
#   '感恩',
#   '还',
#   '这样',
#   '对待',
#   '自己',
#   '的',
#   '母亲',
#   '谁',
#   '能',
#   '容忍',
#   '估计',
#   '儿子',
#   '动手',
#   '那一刻',
#   '老',
#   '母亲',
#   '就',
#   '懵',
#   '了'],
#  ['鹿彤',
#   '最近',
#   '总有',
#   '八卦',
#   '大号',
#   '发鹿',
#   '哥和晓彤',
#   '最近',
#   '老',
#   '吵架',
#   '感情',
#   '越来越',
#   '淡',
#   '真的假',
#   '的',
#   '啊',
#   '有人',
#   '知道',
#   '他俩',
#   '现在',
#   '什么',
#   '情况',
#   '吗',
#   '急'],
#  ['西班牙',
#   '搞',
#   '什么',
#   '鬼',
#   '啊',
#   '就',
#   '因为',
#   '主帅',
#   '是',
#   '皇马',
#   '主帅',
#   '好歹',
#   '带',
#   '完',
#   '这',
#   '一届',
#   '世界杯',
#   '啊',
#   '懵',
#   '逼',
#   '简直'],
#  ['营长',
#   '冀',
#   '红',
#   '朋友',
#   '捡',
#   '到',
#   '一个',
#   '高考',
#   '准考证',
#   '谁',
#   '认识',
#   '通知',
#   '下',
#   '别',
#   '耽误',
#   '了',
#   '高考',
#   '大事',
#   '白娅倩',
#   '考点',
#   '一中',
#   '考场',
#   '座',
#   '号',
#   '准考证号',
#   '请',
#   '大家',
#   '帮忙',
#   '互相',
#   '转发',
#   '别',
#   '耽误',
#   '了',
#   '孩子',
#   '高考',
#   '联系电话',
#   '群里发',
#   '的',
#   '不',
#   '知道',
#   '真假',
#   '但',
#   '希望',
#   '那个',
#   '考生',
#   '能够',
#   '找到',
#   '中山西路',
#   '骗人',
#   '将',
#   '勿',
#   '信',
#   '盲目',
#   '跟风',
#   '旧',
#   '的',
#   '不能',
#   '再',
#   '旧',
#   '的',
#   '新闻',
#   '了',
#   '小心',
#   '警察',
#   '找',
#   '你',
#   '麻烦',
#   '怀疑',
#   '你',
#   '诈骗',
#   '回复',
#   '宝',
#   '勒尔',
#   '我',
#   '是',
#   '好心',
#   '的',
#   '不',
#   '知道',
#   '回复',
#   '玉行',
#   '的',
#   '博'],
#  ['再次',
#   '爆',
#   '猛料',
#   '姓',
#   '女星',
#   '多次',
#   '怂恿',
#   '其他',
#   '女艺人',
#   '做',
#   '头发',
#   '网传',
#   '女星',
#   '特别',
#   '喜欢',
#   '蹭',
#   '热度',
#   '这下',
#   '不用',
#   '蹭',
#   '了',
#   '终于',
#   '自己',
#   '成',
#   '舆论',
#   '焦点',
#   '了',
#   '马苏',
#   '回应',
#   '马苏',
#   '黑',
#   '历史',
#   '李小璐',
#   '北',
#   '九片',
#   '海',
#   '你',
#   '说',
#   '和',
#   '李小璐',
#   '的',
#   '做',
#   '头发',
#   '是不是',
#   '有',
#   '关系'],
#  ['区块',
#   '链',
#   '虚拟',
#   '货币',
#   '市场',
#   '到底',
#   '有多火',
#   '网传',
#   '某',
#   '手机',
#   '系统',
#   '带',
#   '虚拟',
#   '货币',
#   '钱包',
#   '功能',
#   '了',
#   '魅族',
#   '吗',
#   '跟',
#   '我',
#   '界面',
#   '一样',
#   '吃瓜',
#   '魅族币',
#   '评论',
#   '配图'],
#  ['分享',
#   '网易',
#   '新闻',
#   '网传',
#   '江苏',
#   '一',
#   '养老院',
#   '位',
#   '老人',
#   '被',
#   '热',
#   '死',
#   '院方',
#   '正常',
#   '死亡',
#   '来自',
#   '网易',
#   '新闻',
#   '客户端',
#   '我',
#   '在',
#   '看',
#   '新闻'],
#  ['正常人',
#   '不',
#   '需要',
#   '掏耳朵',
#   '从',
#   '医学',
#   '上',
#   '说',
#   '正常人',
#   '不',
#   '需要',
#   '掏耳朵',
#   '耵聍',
#   '耳屎',
#   '可',
#   '阻碍',
#   '声波',
#   '对',
#   '鼓膜',
#   '的',
#   '伤害',
#   '有',
#   '抑菌',
#   '杀菌作用',
#   '耵聍',
#   '会',
#   '随着',
#   '张口',
#   '打哈欠',
#   '等',
#   '自动',
#   '脱落',
#   '排出',
#   '体外',
#   '随意',
#   '掏耳朵',
#   '可能',
#   '引起',
#   '中耳炎',
#   '导致',
#   '听力',
#   '下降',
#   '刺激',
#   '耵聍',
#   '分泌',
#   '形成',
#   '栓塞',
#   '低调',
#   '炫技',
#   '杨淼',
#   '任',
#   '小羊',
#   '喜欢',
#   '买买',
#   '买',
#   '真的假',
#   '的',
#   '我',
#   '每',
#   '三四天',
#   '就',
#   '用',
#   '棉签',
#   '掏耳朵',
#   '但是',
#   '掏耳朵',
#   '真的',
#   '很爽',
#   '啊',
#   '邓可',
#   '尴尬',
#   '了',
#   '万小',
#   '猴儿',
#   '儿',
#   '但是',
#   '如果',
#   '一段时间',
#   '不',
#   '掏耳朵',
#   '耳朵',
#   '就',
#   '会',
#   '奇痒',
#   '无比',
#   '所以',
#   '在',
#   '你',
#   '痒',
#   '的',
#   '不能自已',
#   '的',
#   '时候',
#   '应该',
#   '怎么办',
#   '二哈',
#   '掏耳朵',
#   '是',
#   '一种',
#   '享受',
#   '和',
#   '那',
#   '什么',
#   '来',
#   '比',
#   '无害',
#   '那',
#   '我',
#   '同事',
#   '的',
#   '铁',
#   '耳屎',
#   '是',
#   '这么回事',
#   '人',
#   '叫',
#   '她',
#   '她',
#   '都',
#   '听不见',
#   '后来',
#   '去',
#   '医院',
#   '掏出',
#   '来',
#   '之后',
#   '世界',
#   '都',
#   '听',
#   '清',
#   '了',
#   '何星',
#   '耳屎',
#   '是',
#   '潮',
#   '的',
#   '是',
#   '怎么回事',
#   '可爱',
#   '哆',
#   '哆',
#   '哆',
#   '还',
#   '可以',
#   '这样',
#   '啊',
#   '翟成',
#   '成瑾',
#   '衰',
#   '没出息',
#   '没',
#   '毅力',
#   '以后',
#   '别扣',
#   '了',
#   '现在',
#   '就',
#   '马上',
#   '你',
#   '附近',
#   '的',
#   '棉签',
#   '来',
#   '一发',
#   '吧',
#   '问题',
#   '是',
#   '掏耳朵',
#   '是',
#   '一件',
#   '很爽',
#   '的',
#   '事情',
#   '绿时',
#   '我',
#   '在',
#   '学校',
#   '学医',
#   '的',
#   '时候',
#   '五官科',
#   '的',
#   '老师',
#   '说',
#   '了',
#   '人',
#   '进化',
#   '这么久',
#   '了',
#   '身体',
#   '每个',
#   '部位',
#   '都',
#   '很',
#   '成熟',
#   '它',
#   '能',
#   '自己',
#   '解决',
#   '的',
#   '不要',
#   '没事',
#   '去动',
#   '它',
#   '超级',
#   '月亮',
#   '不',
#   '掏',
#   '那',
#   '痒',
#   '的',
#   '受不了',
#   '靠',
#   '甩',
#   '怪不得',
#   '那么',
#   '多人',
#   '磕',
#   '摇头丸',
#   '原来',
#   '是',
#   '耳朵',
#   '痒',
#   '小小',
#   '菲',
#   '呵呵',
#   '呵',
#   '北燕',
#   '飞',
#   '吧',
#   '她',
#   '大舅',
#   '她',
#   '二舅',
#   '都',
#   '是',
#   '她',
#   '舅舅',
#   '遇',
#   '你',
#   '我',
#   '天色',
#   '常蓝',
#   '的',
#   '意思',
#   '不是',
#   '吃惊',
#   '吃惊',
#   '吃惊',
#   '水蜜桃',
#   '大',
#   '妹妹',
#   '评论',
#   '都',
#   '是',
#   '科学知识',
#   '摊手',
#   '摊手',
#   '我爱路',
#   '缘',
#   '思考',
#   '苏家屯',
#   '韦斯特',
#   '布鲁克',
#   '文博',
#   '你',
#   '瞅',
#   '瞅',
#   '第一个',
#   '评论',
#   '吧',
#   '奇怪',
#   '我',
#   '以前',
#   '那么',
#   '爱笑',
#   '自己',
#   '看',
#   '我',
#   '岁',
#   '上',
#   '医院',
#   '挖',
#   '了',
#   '坨',
#   '大',
#   '耳屎',
#   '当场',
#   '感觉',
#   '周围',
#   '人',
#   '的',
#   '声音',
#   '都',
#   '像',
#   '拿',
#   '着',
#   '麦克风',
#   '说话',
#   '音量',
#   '灿若',
#   '樱夏',
#   '韩',
#   '雷锋',
#   '樊',
#   '所以',
#   '以后',
#   '不要',
#   '掏',
#   '了',
#   '叶',
#   '爸爸',
#   '爸',
#   '哈哈',
#   '晴朗',
#   '是',
#   '蓝色',
#   '的',
#   '鼻屎',
#   '用',
#   '不用',
#   '掏'],
#  ['急',
#   '找',
#   '孩子',
#   '求转',
#   '寻人启事',
#   '扩散',
#   '今天上午',
#   '一个三岁',
#   '多',
#   '小女孩',
#   '在',
#   '合阳县',
#   '三中',
#   '附近',
#   '被',
#   '人',
#   '拐走',
#   '小女孩',
#   '能',
#   '说出',
#   '她',
#   '爸爸',
#   '的',
#   '手机号码',
#   '从',
#   '监控',
#   '上',
#   '看',
#   '是',
#   '被',
#   '一个四十多岁',
#   '男人',
#   '抱',
#   '走',
#   '了',
#   '现',
#   '大人',
#   '都',
#   '急',
#   '疯',
#   '了',
#   '有',
#   '知情者',
#   '请告',
#   '之',
#   '万分',
#   '感谢',
#   '看到',
#   '信息',
#   '的',
#   '兄弟姐妹',
#   '留意',
#   '一下',
#   '联系人',
#   '石',
#   '建军',
#   '我们',
#   '都',
#   '会',
#   '有',
#   '孩子',
#   '谢谢',
#   '你',
#   '必有',
#   '重谢',
#   '万元',
#   '什么',
#   '情况'],
#  ['帮忙',
#   '转发',
#   '一下',
#   '一位',
#   '叫',
#   '徐敬',
#   '的',
#   '女孩',
#   '岁',
#   '请',
#   '速回',
#   '雅安',
#   '水城县',
#   '人民',
#   '医院',
#   '妈妈',
#   '伤',
#   '的',
#   '很',
#   '严重',
#   '想见',
#   '她',
#   '最后',
#   '一面',
#   '爸爸',
#   '号码',
#   '爱心',
#   '接力',
#   '好人',
#   '有',
#   '好',
#   '报',
#   '哈',
#   '喽',
#   '美女',
#   '必须',
#   '帮',
#   '你',
#   '转起',
#   '你',
#   '的',
#   '行为',
#   '深深感动',
#   '了',
#   '我',
#   '希望',
#   '她',
#   '妈妈',
#   '坚持',
#   '住',
#   '爱',
#   '夹牙',
#   '爱',
#   '拼',
#   '才',
#   '回',
#   '赢',
#   '蜡烛',
#   '爱',
#   '你',
#   '蜡烛',
#   '爱',
#   '你',
#   '蜡烛',
#   '蜡烛',
#   '蜡烛',
#   '蜡烛',
#   '我',
#   '是',
#   '你',
#   '的',
#   '唯一',
#   '留言',
#   '者',
#   '你',
#   '居然',
#   '不回',
#   '我',
#   '我',
#   '生气',
#   '了',
#   '怒',
#   '怒',
#   '怒',
#   '删',
#   '了',
#   '吧',
#   '别人',
#   '乱传',
#   '的',
#   '回复',
#   '小古',
#   '删不掉',
#   '汗',
#   '回复',
#   '赵艺',
#   '喔',
#   '可能',
#   '被',
#   '新浪',
#   '处理',
#   '过',
#   '打',
#   '上',
#   '标记',
#   '了',
#   '吧',
#   '衰',
#   '回复',
#   '小古',
#   '那',
#   '咋办',
#   '举报',
#   '那个',
#   '人',
#   '也',
#   '是',
#   '直接',
#   '跟',
#   '我',
#   '说',
#   '嘛',
#   '我',
#   '直接',
#   '删',
#   '了',
#   '就是',
#   '了',
#   '汗',
#   '回复',
#   '赵艺',
#   '请',
#   '微博',
#   '小秘书',
#   '帮忙',
#   '删下',
#   '这条',
#   '微博',
#   '信息',
#   '吧',
#   '博主',
#   '早点',
#   '休息',
#   '吧',
#   '晚安',
#   '月亮',
#   '爱心',
#   '传递',
#   '爱心',
#   '传递',
#   '爱心',
#   '传递',
#   '爱心',
#   '传递',
#   '爱心',
#   '传递',
#   '你',
#   '啷',
#   '个',
#   '晓得',
#   '是',
#   '假',
#   '的',
#   '了',
#   '啊',
#   '回复',
#   '舌甘',
#   '寶兒',
#   '着',
#   '被',
#   '人据',
#   '报老',
#   '汗',
#   '回复',
#   '赵艺',
#   '就是',
#   '看',
#   '了',
#   '你',
#   '这个',
#   '下午',
#   '我',
#   '睡',
#   '了',
#   '还',
#   '做',
#   '了',
#   '个',
#   '梦',
#   '梦到',
#   '啊',
#   '多',
#   '他们',
#   '还',
#   '寄',
#   '了',
#   '七千块',
#   '钱',
#   '过去',
#   '赞助',
#   '结婚',
#   '是',
#   '骗局'],
#  ['中国',
#   '人',
#   '拍',
#   '的',
#   '金陵',
#   '十三',
#   '钗',
#   '小',
#   '日本',
#   '让',
#   '其',
#   '票房',
#   '为',
#   '零',
#   '小',
#   '日本',
#   '拍',
#   '的',
#   '贞子',
#   '将',
#   '亍',
#   '月',
#   '日',
#   '在',
#   '中国',
#   '大陆',
#   '上映',
#   '而',
#   '月',
#   '日',
#   '既',
#   '是',
#   '南京大屠杀',
#   '纪念日',
#   '勿忘',
#   '国耻',
#   '作为',
#   '中国',
#   '人',
#   '必须',
#   '让贞子',
#   '票房',
#   '为',
#   '零',
#   '朋友',
#   '们',
#   '同胞们',
#   '拿',
#   '起',
#   '你',
#   '的',
#   '鼠标',
#   '复制',
#   '然后',
#   '粘贴',
#   '一下',
#   '转起',
#   '转起',
#   '胡白',
#   '传奇',
#   '简颜',
#   '潘旺众',
#   '童浩',
#   '婚礼',
#   '团队',
#   '济南',
#   '彩云',
#   '间',
#   '婚礼',
#   '韩旭红',
#   '太原',
#   '张',
#   '和',
#   '谁',
#   '看',
#   '日',
#   '谁',
#   '偷笑',
#   '偷笑',
#   '偷笑',
#   '回去',
#   '看看',
#   '教科书',
#   '再来',
#   '发微博',
#   '么',
#   '文化',
#   '真',
#   '可爱',
#   '转',
#   '坚决',
#   '转',
#   '非常',
#   '司仪',
#   '组',
#   '宁江',
#   '婚礼',
#   '摄影师',
#   '塔塔',
#   '非常',
#   '司仪',
#   '组',
#   '晨光',
#   '非',
#   '著名',
#   '主持人',
#   '杨雄',
#   '跟',
#   '拍',
#   '阿牛',
#   '摄影师',
#   '耗子',
#   '女',
#   '魔术师',
#   '然然',
#   '摄影师',
#   '舍巴',
#   '非常',
#   '司仪',
#   '组',
#   '雨',
#   '霏',
#   '大汉',
#   '倭奴',
#   '小',
#   '日本',
#   '你',
#   '拽',
#   '什么',
#   '胡白',
#   '传奇',
#   '转',
#   '非常',
#   '司仪',
#   '组',
#   '王卓',
#   '非常',
#   '司仪',
#   '组',
#   '波',
#   '司仪',
#   '非常',
#   '司仪',
#   '组',
#   '晨光',
#   '萝亚薇',
#   '薇',
#   '潘旺众',
#   '蔡上',
#   '冉慧聪',
#   '主持人',
#   '坏坏',
#   '不要',
#   '盲目',
#   '的',
#   '看到',
#   '什么',
#   '就',
#   '都',
#   '当',
#   '是',
#   '真的',
#   '而且',
#   '要',
#   '有点',
#   '常识',
#   '好',
#   '么',
#   '南京大屠杀',
#   '纪念日',
#   '是',
#   '月',
#   '日',
#   '再说',
#   '了',
#   '您',
#   '什么',
#   '时候',
#   '看到',
#   '日产',
#   '鬼片',
#   '在',
#   '大陆',
#   '上映',
#   '过',
#   '的',
#   '二货',
#   '当年',
#   '金陵',
#   '就',
#   '没有',
#   '投放',
#   '日本',
#   '市场',
#   '怎么',
#   '能',
#   '有',
#   '票房',
#   '收入',
#   '呢',
#   '搞',
#   '搞清',
#   '再来',
#   '伪',
#   '爱国',
#   '对于',
#   '日本',
#   '军国主义',
#   '讲求',
#   '任何',
#   '形式',
#   '的',
#   '信义',
#   '都',
#   '是',
#   '宋襄公',
#   '式',
#   '的',
#   '愚蠢',
#   '管',
#   '他实',
#   '与',
#   '不实',
#   '借个',
#   '理由',
#   '狠狠',
#   '教训',
#   '他个',
#   '日本',
#   '王八蛋',
#   '十九世纪',
#   '骑',
#   '在',
#   '我们',
#   '脖子',
#   '上',
#   '撒尿',
#   '拉屎',
#   '的',
#   '时代',
#   '一去不复返了',
#   '当然',
#   '对于',
#   '他妈',
#   '都',
#   '嫌',
#   '他',
#   '懒',
#   '之',
#   '汉奸',
#   '者',
#   '流',
#   '除外',
#   '其',
#   '等待',
#   '的',
#   '正是',
#   '其',
#   '日本',
#   '主子',
#   '的',
#   '屎尿',
#   '恩赐',
#   '以促',
#   '其',
#   '邪恶',
#   '生长',
#   '惑乱',
#   '中华',
#   '记住',
#   '历史',
#   '的',
#   '同时',
#   '我们',
#   '却',
#   '不能',
#   '改变',
#   '历史',
#   '希望',
#   '更',
#   '多',
#   '的',
#   '人',
#   '能够',
#   '懂得',
#   '了',
#   '历史',
#   '之后',
#   '努力',
#   '改变',
#   '未来'],
#  ['看到',
#   '不能',
#   '装作',
#   '没',
#   '看到',
#   '帮',
#   '转发',
#   '朋友',
#   '的',
#   '小孩',
#   '叫',
#   '果果',
#   '刚刚',
#   '在',
#   '万达',
#   '广场',
#   '附近',
#   '走',
#   '丢',
#   '麻烦',
#   '帮忙',
#   '发',
#   '下',
#   '争取时间',
#   '谢',
#   '各位',
#   '家长',
#   '请',
#   '照看',
#   '好',
#   '自己',
#   '的',
#   '小孩',
#   '不要',
#   '等',
#   '失去',
#   '的',
#   '时候',
#   '才',
#   '追悔莫及',
#   '有',
#   '在',
#   '万达',
#   '的',
#   '帮忙',
#   '注意',
#   '一下',
#   '孩子',
#   '还',
#   '小',
#   '家里',
#   '很着急'],
#  ['极限',
#   '竞速',
#   '地平线',
#   '公布',
#   '地点',
#   '应该',
#   '是',
#   '欧洲',
#   '游戏',
#   '背景',
#   '设定',
#   '在',
#   '英国',
#   '反正',
#   '不是',
#   '之前',
#   '传言',
#   '的',
#   '亚洲',
#   '这次',
#   '加入',
#   '了',
#   '四季',
#   '系统',
#   '游戏',
#   '的',
#   '画面',
#   '效果',
#   '再次',
#   '提升'],
#  ['币安何',
#   '一',
#   '区块',
#   '链',
#   '对',
#   '我',
#   '来讲',
#   '大概',
#   '是',
#   '九九八十一',
#   '难',
#   '的',
#   '取经',
#   '路',
#   '今日',
#   '币安',
#   '联合',
#   '创始人',
#   '何',
#   '一发',
#   '微博',
#   '评论',
#   '区块',
#   '链',
#   '说道',
#   '无论是',
#   '传言',
#   '再',
#   '不',
#   '抓',
#   '人',
#   '江山',
#   '没',
#   '了',
#   '的',
#   '过度',
#   '妖魔化',
#   '还是',
#   '知名',
#   '大佬',
#   '疾呼',
#   '再',
#   '不',
#   '上车',
#   '就',
#   '落伍',
#   '了',
#   '的',
#   '过度',
#   '神话',
#   '都',
#   '不是',
#   '区块',
#   '链',
#   '真实',
#   '的',
#   '样子',
#   '她',
#   '认为',
#   '区块',
#   '链是',
#   '什么',
#   '对',
#   '她',
#   '来讲',
#   '大概',
#   '是',
#   '九九八十一',
#   '难',
#   '的',
#   '取经',
#   '路',
#   '并',
#   '表示',
#   '旁人',
#   '看来',
#   '取经',
#   '的',
#   '和尚',
#   '也',
#   '长',
#   '妖怪',
#   '模样',
#   '哪有什么',
#   '分别',
#   '但',
#   '你',
#   '知道',
#   '自己',
#   '作为',
#   '和尚',
#   '该',
#   '斩妖',
#   '还',
#   '得',
#   '斩妖',
#   '该',
#   '除魔',
#   '还',
#   '得',
#   '除魔',
#   '虽',
#   '有',
#   '日行千里',
#   '之技',
#   '但',
#   '该',
#   '走',
#   '的',
#   '路',
#   '一步',
#   '不会',
#   '少'],
#  ['发表',
#   '了',
#   '博文',
#   '董氏',
#   '奇穴',
#   '特色',
#   '疗法',
#   '专题技术',
#   '临床',
#   '应用',
#   '研修班',
#   '一',
#   '课题',
#   '介绍',
#   '董氏',
#   '奇穴',
#   '针灸疗法',
#   '传承',
#   '于',
#   '台湾',
#   '盛行于',
#   '海外',
#   '近年来',
#   '风行',
#   '于',
#   '世界',
#   '董氏',
#   '奇穴',
#   '是',
#   '董景昌',
#   '先生',
#   '祖传',
#   '针灸',
#   '绝技',
#   '嫡传',
#   '弟子',
#   '杨维',
#   '杰',
#   '先生',
#   '将',
#   '董氏',
#   '奇穴',
#   '发扬',
#   '董氏',
#   '奇穴',
#   '特色',
#   '疗法',
#   '专题技术',
#   '临床',
#   '应用',
#   '研修班'],
#  ['帮忙',
#   '发',
#   '一条',
#   '救命',
#   '信息',
#   '急需',
#   '阴性',
#   '血',
#   '救命之恩',
#   '必有',
#   '重谢',
#   '电话',
#   '都',
#   '帮忙',
#   '发',
#   '一发',
#   '真实',
#   '的',
#   '伤者',
#   '在',
#   '第一',
#   '医院',
#   '抢救',
#   '是',
#   '消防官兵',
#   '看到',
#   '发',
#   '一下',
#   '啊',
#   '各位',
#   '没准',
#   '动动',
#   '您',
#   '的',
#   '手指',
#   '就',
#   '救',
#   '了',
#   '一条',
#   '人命',
#   '重庆',
#   '南路',
#   '辟谣',
#   '温州',
#   '消防',
#   '近日',
#   '众多',
#   '谣言',
#   '流传',
#   '温州',
#   '消防官兵',
#   '受伤',
#   '需要',
#   '阴性',
#   '血',
#   '请',
#   '广大',
#   '市民',
#   '不要',
# ...
#   '接受',
#   '其他',
#   '安排',
#   '的',
#   '三',
#   '因'],
#  ['我',
#   '本来',
#   '想',
#   '在',
#   '百度',
#   '百科',
#   '上',
#   '编辑',
#   '我',
#   '的',
#   '词条',
#   '去掉',
#   '哈佛',
#   '博士后',
#   '那个',
#   '结果',
#   '通不过',
#   '说',
#   '我',
#   '传播',
#   '虚假',
#   '消息',
#   '这个',
#   '北',
#   '大学',
#   '霸',
#   '的',
#   '故事',
#   '够',
#   '荒诞',
#   '一切都是',
#   '假',
#   '的',
#   '年',
#   '来',
#   '却',
#   '感动',
#   '了',
#   '无数',
#   '人',
#   '这个',
#   '北',
#   '大学'],
#  ['阜阳',
#   '身边',
#   '事',
#   '时',
#   '分',
#   '阜阳',
#   '高速',
#   '三',
#   '大队',
#   '民警',
#   '在济广',
#   '高速',
#   '公里',
#   '处',
#   '接到',
#   '亳州',
#   '方向',
#   '南下',
#   '的',
#   '大批',
#   '车辆',
#   '两地',
#   '高速',
#   '交警',
#   '接力',
#   '护送',
#   '警车',
#   '压速',
#   '带',
#   '道',
#   '阜阳',
#   '公安',
#   '交'],
#  ['评论',
#   '马进彪',
#   '时评',
#   '的',
#   '博文',
#   '坠井',
#   '男童',
#   '家属',
#   '殴打',
#   '医务人员',
#   '可以',
#   '谅解',
#   '吗',
#   '如果',
#   '所谓',
#   '的',
#   '打人',
#   '事件',
#   '真的',
#   '根本',
#   '就',
#   '不',
#   '存在',
#   '的话',
#   '这些',
#   '唯恐天下',
#   '不乱',
#   '的',
#   '造谣',
#   '的',
#   '传谣',
#   '的',
#   '应该',
#   '承担',
#   '什么',
#   '责任',
#   '呢',
#   '查看',
#   '原文',
#   '坠井',
#   '男童',
#   '家'],
#  ['刚',
#   '毕业',
#   '的',
#   '时候',
#   '在',
#   '杭州',
#   '工作',
#   '过',
#   '半年',
#   '特别',
#   '喜欢',
#   '这座',
#   '城市',
#   '它',
#   '的',
#   '市容',
#   '服务水平',
#   '单车',
#   '管理',
#   '旅游景点',
#   '的',
#   '整洁',
#   '干净',
#   '夜晚',
#   '的',
#   '宁静',
#   '唯一',
#   '感觉',
#   '不足',
#   '的',
#   '是',
#   '少',
#   '了',
#   '点烟',
#   '火气',
#   '有',
#   '可能',
#   '与',
#   '我',
#   '住',
#   '的',
#   '地方',
#   '有',
#   '关系',
#   '后来',
#   '由于',
#   '工作',
#   '原因',
#   '陆陆续续',
#   '去',
#   '了',
#   '很多',
#   '城市',
#   '也',
#   '包括',
#   '一些',
#   '海外',
#   '的',
#   '城市',
#   '基本',
#   '找',
#   '不',
#   '回',
#   '当时',
#   '的',
#   '感觉',
#   '啦',
#   '喜欢',
#   '杭州',
#   '值得',
#   '定居',
#   '的',
#   '城市',
#   '展开',
#   '全文'],
#  ['马化腾',
#   '谈',
#   '区块',
#   '链',
#   '与',
#   '虚拟',
#   '货币',
#   '网传',
#   '马化腾',
#   '朋友圈',
#   '截图',
#   '他',
#   '转',
#   '张首晟',
#   '教授',
#   '区块',
#   '链',
#   '技术',
#   '是',
#   '互联网',
#   '世界',
#   '新',
#   '的',
#   '分合',
#   '转折点',
#   '时',
#   '评论',
#   '道',
#   '目前',
#   '众多',
#   '公共',
#   '区块',
#   '链',
#   '消耗',
#   '大量',
#   '能源',
#   '计算力',
#   '生产',
#   '虚',
#   '数字',
#   '币',
#   '到底',
#   '算有',
#   '等价物',
#   '背书',
#   '吗',
#   '如',
#   '按',
#   '生命',
#   '理论',
#   '应该',
#   '很多',
#   '生命',
#   '系统',
#   '会',
#   '不断',
#   '演化',
#   '淘汰'],
#  ['关注',
#   '一线',
#   '警察',
#   '又',
#   '见',
#   '女子',
#   '掌',
#   '掴',
#   '警察',
#   '好',
#   '厉害',
#   '的',
#   '女子',
#   '好',
#   '窝囊',
#   '的',
#   '警察',
#   '厨子',
#   '磨刀',
#   '警察',
#   '出去',
#   '执法',
#   '就',
#   '真的',
#   '是',
#   '挨打',
#   '的',
#   '吗',
#   '胖子',
#   '陈越',
#   '的',
#   '把',
#   '他',
#   '孩子',
#   '送',
#   '去',
#   '当',
#   '警察',
#   '吧',
#   '怒',
#   '怒',
#   '顶风',
#   '作案',
#   '严肃处理',
#   '坐等',
#   '结果',
#   '胖子',
#   '陈越',
#   '天中',
#   '捕快',
#   '韩东言',
#   '赵',
#   '不是',
#   '钢城',
#   '民警',
#   '钢城',
#   '小女警',
#   '胖子',
#   '陈越',
#   '法医',
#   '秦明',
#   '天中',
#   '捕快',
#   '吉吉福',
#   '进行',
#   '中',
#   '阿勒泰',
#   '公安',
#   '在线',
#   '共青团中央',
#   '公安部',
#   '打四黑',
#   '除四害',
#   '崔紫剑',
#   '先生',
#   '带刀',
#   '小',
#   '捕快',
#   '孤烟',
#   '暮',
#   '蝉',
#   '博主',
#   '我能',
#   '不能',
#   '求',
#   '你',
#   '一件',
#   '事儿',
#   '你',
#   '把',
#   '事情',
#   '描述',
#   '清楚',
#   '啊',
#   '允悲',
#   '就',
#   '这',
#   '执法',
#   '能力',
#   '和',
#   '水平',
#   '我',
#   '真',
#   '怀疑',
#   '是不是',
#   '警察',
#   '日常',
#   '被',
#   '打',
#   '二哈',
#   '幸亏',
#   '是',
#   '在',
#   '中国',
#   '在',
#   '某些',
#   '国家',
#   '有',
#   '可能',
#   '会',
#   '吃',
#   '枪子',
#   '对',
#   '袭警',
#   '说',
#   '不',
#   '哪里',
#   '的',
#   '事',
#   '具体',
#   '什么',
#   '情况',
#   '当地政府',
#   '公安部门',
#   '是不是',
#   '应该',
#   '发声',
#   '了',
#   '打铁',
#   '还',
#   '需',
#   '自身',
#   '硬',
#   '思考',
#   '辣椒水',
#   '干嘛',
#   '不用',
#   '回家',
#   '拌面',
#   '啊',
#   '这',
#   '警察',
#   '好',
#   '可怜',
#   '有没有',
#   '后续',
#   '报道',
#   '呀',
#   '博主',
#   '黑线',
#   '在',
#   '米国',
#   '直接',
#   '吃',
#   '枪子儿',
#   '了',
#   '人民公仆',
#   '人民',
#   '奴隶',
#   '这种',
#   '人先',
#   '制服',
#   '了',
#   '算',
#   '不',
#   '还手',
#   '是',
#   '对',
#   '的',
#   '但是',
#   '人民警察',
#   '的',
#   '尊严',
#   '何在',
#   '微笑',
#   '好',
#   '厉害',
#   '的',
#   '女子',
#   '好',
#   '悲惨',
#   '的',
#   '警察',
#   '警察',
#   '出去',
#   '执法',
#   '就是',
#   '去',
#   '挨打',
#   '吗',
#   '遇到',
#   '这种',
#   '情况',
#   '除了',
#   '一动不动',
#   '站',
#   '着',
#   '挨打',
#   '难道',
#   '一点',
#   '其他',
#   '措施',
#   '都',
#   '不会',
#   '采取',
#   '嘛',
#   '怒',
#   '强烈',
#   '谴责',
#   '这种',
#   '打人',
#   '的',
#   '以外',
#   '也',
#   '该',
#   '反思',
#   '一下',
#   '我们',
#   '的',
#   '交通警察',
#   '为什么',
#   '现场',
#   '不能',
#   '硬气',
#   '一点',
#   '依法',
#   '传唤',
#   '她',
#   '法律',
#   '尊严',
#   '扫地',
#   '违法',
#   '成本低',
#   '啊',
#   '成本低',
#   '怒',
#   '怒',
#   '怒',
#   '不管',
#   '被',
#   '掌',
#   '掴',
#   '的',
#   '是',
#   '警察',
#   '还是',
#   '普通人',
#   '这样',
#   '打人',
#   '的',
#   '女人',
#   '都',
#   '应该',
#   '摁',
#   '倒',
#   '猛揍',
#   '一',
#   '警告',
#   '二上',
#   '铐',
#   '三',
#   '带走',
#   '不行',
#   '再',
#   '上',
#   '辣椒水',
#   '不信治',
#   '不了',
#   '一个',
#   '女子',
#   '天中',
#   '捕快',
#   '丢人',
#   '警校',
#   '小李',
#   '有',
#   '危难',
#   '找',
#   '警察',
#   '随便',
#   '打',
#   '怒',
#   '弱',
#   '怒',
#   '怒',
#   '怒',
#   '刑拘',
#   '怒',
#   '怒',
#   '怒',
#   '直接',
#   '摞',
#   '倒',
#   '抓捕',
#   '白帽',
#   '蓝衣',
#   '哦',
#   '很',
#   '牛',
#   '吗',
#   '警察',
#   '窝囊',
#   '就是',
#   '窝囊',
#   '别',
#   '找',
#   '那么',
#   '多',
#   '借口',
#   '肥猫',
#   '小',
#   '仔仔',
#   '回复',
#   '玮',
#   '博',
#   '网友',
#   '爆料',
#   '该',
#   '女子',
#   '系',
#   '河北省',
#   '唐山市',
#   '海港',
#   '开发区',
#   '国税局',
#   '某',
#   '赵姓',
#   '副局长',
#   '的',
#   '夫人',
#   '你们',
#   '终于',
#   '知道',
#   '她',
#   '是',
#   '为何',
#   '这样',
#   '的',
#   '牛',
#   '逼',
#   '了',
#   '吧',
#   '玮',
#   '博',
#   '博主',
#   '我能',
#   '不能',
#   '求',
#   '你',
#   '一件',
#   '事儿',
#   '你',
#   '把',
#   '事情',
#   '描述',
#   '清楚',
#   '啊',
#   '怒',
#   '摊手',
#   '怒',
#   '怒',
#   '允悲',
#   '怒',
#   '是',
#   '我',
#   '早就',
#   '摔',
#   '地上',
#   '了',
#   '这',
#   '不是',
#   '再',
#   '打',
#   '民警',
#   '是',
#   '在',
#   '打',
#   '法律',
#   '过分',
#   '法办',
#   '了',
#   '吗',
#   '怒',
#   '怒',
#   '执法者',
#   '太',
#   '怂',
#   '估计',
#   '是',
#   '被',
#   '气势汹汹',
#   '的',
#   '泼妇',
#   '吓倒',
#   '不敢',
#   '大胆',
#   '执法',
#   '怕',
#   '她',
#   '的',
#   '后台',
#   '怕',
#   '引祸',
#   '上身',
#   '但',
#   '你们',
#   '是',
#   '警察',
#   '啊',
#   '连',
#   '警察',
#   '都',
#   '不敢',
#   '对',
#   '违法者',
#   '采取措施',
#   '一般',
#   '的',
#   '平民',
#   '老百姓',
#   '岂',
#   '不是',
#   '更',
#   '不敢',
#   '见义勇为',
#   '了',
#   '除了',
#   '要遣责',
#   '这个',
#   '副局长',
#   '的',
#   '泼妇',
#   '夫人',
#   '外',
#   '作为',
#   '警察',
#   '自身',
#   '更',
#   '应该',
#   '反思',
#   '吃瓜',
#   '深夜',
#   '跑堂',
#   '晚安',
#   '好',
#   '梦',
#   '喝了酒',
#   '就',
#   '去',
#   '打',
#   '警察',
#   '啊',
#   '有',
#   '啥',
#   '好',
#   '怕',
#   '的',
#   '反正',
#   '他们',
#   '又',
#   '不敢',
#   '打',
#   '咱',
#   '打',
#   '了',
#   '咱',
#   '就',
#   '录下来',
#   '发',
#   '网上',
#   '去',
#   '然后',
#   '会',
#   '有',
#   '一堆',
#   '公汁',
#   '来',
#   '帮忙',
#   '的',
#   '挖',
#   '鼻',
#   '狂犬',
#   '女',
#   '遇到',
#   '无卵',
#   '警察',
#   '兵团',
#   '在线',
#   '顶格',
#   '处理',
#   '义勇军',
#   '微',
#   '尘土',
#   '作威作福',
#   '惯',
#   '了',
#   '不知天高地厚',
#   '蔡',
#   '小心',
#   '警营',
#   '微报员',
#   '这个',
#   '女子',
#   '好',
#   '厉害',
#   '吆',
#   '不',
#   '知道',
#   '这会',
#   '她',
#   '在',
#   '什么',
#   '地方',
#   '肥猫',
#   '小',
#   '仔仔',
#   '回复',
#   '玮',
#   '博',
#   '网友',
#   '爆料',
#   '该',
#   '女子',
#   '系',
#   '河北省',
#   '唐山市',
#   '海港',
#   '开发区',
#   '国税局',
#   '某',
#   '赵姓',
#   '副局长',
#   '的',
#   '夫人',
#   '你们',
#   '终于',
#   '知道',
#   '她',
#   '为何',
#   '这样',
#   '的',
#   '牛',
#   '怒',
#   '怒',
#   '怒',
#   '怒',
#   '怒',
#   '怒',
#   '围观',
#   '开发区',
#   '国税局',
#   '副局长',
#   '很大',
#   '吗',
#   '正处',
#   '一般',
#   '还',
#   '没到',
#   '呢',
#   '也许',
#   '就是',
#   '个',
#   '副处级',
#   '警察',
#   '到底',
#   '被',
#   '什么',
#   '拴住',
#   '了',
#   '执法权',
#   '都',
#   '被',
#   '打',
#   '蒙',
#   '了',
#   '说',
#   '说',
#   '不过',
#   '人家',
#   '还',
#   '被',
#   '人家',
#   '打',
#   '去',
#   '哎',
#   '丢人',
#   '伤心',
#   '伤心',
#   '伤心',
#   '必须',
#   '法办',
#   '天中',
#   '捕快',
#   '丢人',
#   '警校',
#   '小李',
#   '有',
#   '危难',
#   '找',
#   '警察',
#   '随便',
#   '打',
#   '弱',
#   '怒',
#   '唐山',
#   '交警',
#   '唐山',
#   '交警支队',
#   '督察',
#   '在线',
#   '唐山',
#   '公安',
#   '网络',
#   '发言人',
#   '仲春',
#   '清网',
#   '旗帜',
#   '求是',
#   '紫光阁',
#   '共青团中央',
#   '深圳',
#   '小天',
#   '种花',
#   '家',
#   '的',
#   '小',
#   '捕快',
#   '文艺',
#   '泽',
#   '开发区',
#   '国税局',
#   '副局长',
#   '很大',
#   '吗',
#   '正处',
#   '一般',
#   '还',
#   '没到',
#   '呢',
#   '也许',
#   '就是',
#   '个',
#   '副处级',
#   '警察',
#   '到底',
#   '被',
#   '什么',
#   '拴住',
#   '了',
#   '执法权',
#   '都',
#   '被',
#   '打',
#   '蒙',
#   '了',
#   '说',
#   '说',
#   '不过',
#   '人家',
#   '还',
#   '被',
#   '人家',
#   '打',
#   '去',
#   '哎',
#   '丢人',
#   '伤心',
#   '伤心',
#   '伤心',
#   '亮剑微',
#   '时评',
#   '警察',
#   '依法',
#   '行使职权',
#   '应',
#   '包括',
#   '治服',
#   '暴力',
#   '妨碍',
#   '公务',
#   '的',
#   '人',
#   '你',
#   '这样',
#   '打',
#   '不',
#   '还手',
#   '是',
#   '对',
#   '警察',
#   '公权',
#   '的',
#   '亵渎',
#   '法官',
#   '说法',
#   '必须',
#   '依法',
#   '维护',
#   '警察',
#   '权益',
#   '保障',
#   '警察',
#   '依法执法',
#   '民警',
#   '小唐',
#   '钢城',
#   '民警',
#   '永华',
#   '的',
#   '小',
#   '菜园',
#   '有',
#   '情绪',
#   '找',
#   '警察',
#   '免费',
#   '出气',
#   '把',
#   '你',
#   '夸',
#   '关注',
#   '胖子',
#   '陈越',
#   '回复',
#   '肥猫',
#   '小',
#   '仔仔',
#   '求证',
#   '一下',
#   '守护',
#   '夏都',
#   '易辩',
#   '雷家茂',
#   '天中',
#   '捕快',
#   '眉中王',
#   '老马',
#   '自奋蹄',
#   '阿贵',
#   '时评',
#   '阿木',
#   '德布',
#   '巴顿',
#   '小哥',
#   '话筒'],
#  ['月',
#   '日',
#   '中共',
#   '海南省',
#   '七届',
#   '一次',
#   '全会',
#   '选举',
#   '产生',
#   '省委',
#   '领导班子',
#   '刘赐贵',
#   '当选',
#   '省委书记',
#   '沈晓明',
#   '李军',
#   '当选',
#   '省委',
#   '副',
#   '书记',
#   '新一届',
#   '海南',
#   '省委常委',
#   '班子',
#   '具体',
#   '名单',
#   '是',
#   '刘赐贵',
#   '沈晓明',
#   '李军',
#   '毛超峰',
#   '王瑞连',
#   '张琦',
#   '胡',
#   '光辉',
#   '蓝佛安',
#   '肖莺子',
#   '女',
#   '壮族',
#   '肖杰',
#   '严朝君',
#   '张韵声',
#   '月',
#   '日',
#   '下午',
#   '刘赐',
#   '贵率'],
#  ['中国',
#   '人',
#   '不能',
#   '搞',
#   '种族主义',
#   '绝不能',
#   '现在',
#   '不是',
#   '清朝',
#   '中国',
#   '要',
#   '发展',
#   '外籍人',
#   '土',
#   '往来',
#   '交流',
#   '那',
#   '是',
#   '必然',
#   '男子',
#   '疑似',
#   '在',
#   '广州',
#   '地铁',
#   '言语',
#   '侮辱',
#   '黑人',
#   '遭',
#   '两次',
#   '掌',
#   '掴'],
#  ['班主任',
#   '录',
#   '视频',
#   '指',
#   '学生',
#   '偷笔',
#   '区',
#   '教育局',
#   '就算',
#   '冤枉',
#   '多大点',
#   '事',
#   '贵州',
#   '贵阳',
#   '唐',
#   '先生',
#   '的',
#   '儿子',
#   '被',
#   '班主任',
#   '当',
#   '全班同学',
#   '面',
#   '公开',
#   '指',
#   '认为',
#   '小偷',
#   '并录',
#   '认罪',
#   '视频',
#   '事后',
#   '他',
#   '试图',
#   '与',
#   '班主任',
#   '沟通',
#   '但',
#   '被',
#   '对方',
#   '拉黑',
#   '还',
#   '被',
#   '威胁',
#   '要',
#   '给',
#   '他',
#   '孩子',
#   '特殊',
#   '待遇',
#   '白云区',
#   '教育局',
#   '工作人员',
#   '回应',
#   '就算',
#   '老师',
#   '冤枉',
#   '他',
#   '又',
#   '有',
#   '多',
#   '大事',
#   '贵阳',
#   '一',
#   '班主',
#   '请',
#   '尊重',
#   '他人',
#   '如果',
#   '确有其事',
#   '你',
#   '该',
#   '处分',
#   '就',
#   '处分',
#   '如果',
#   '真的',
#   '是',
#   '被',
#   '冤枉',
#   '那',
#   '你',
#   '教育局',
#   '这种',
#   '无所谓',
#   '的',
#   '态度',
#   '可是',
#   '够',
#   '招人',
#   '恨',
#   '的'],
#  ['朋友',
#   '捡',
#   '到',
#   '一个',
#   '高考',
#   '准考证',
#   '谁',
#   '认识',
#   '通知',
#   '下',
#   '别',
#   '耽误',
#   '了',
#   '高考',
#   '大事',
#   '白娅倩',
#   '考点',
#   '一中',
#   '考场',
#   '座',
#   '号',
#   '准考证号',
#   '请',
#   '大家',
#   '帮忙',
#   '互相',
#   '转发',
#   '别',
#   '耽误',
#   '了',
#   '孩子',
#   '高考',
#   '联系电话',
#   '拥抱',
#   '拥抱',
#   '见到',
#   '的',
#   '请',
#   '帮忙',
#   '转发',
#   '谢谢',
#   '好',
#   '吧',
#   '我',
#   '才',
#   '知道',
#   '这是',
#   '骗人',
#   '的',
#   '别信',
#   '我',
#   '想',
#   '删除',
#   '但',
#   '不',
#   '知道',
#   '哪个',
#   '佬',
#   '举报',
#   '我',
#   '现在',
#   '删除',
#   '不了',
#   '了',
#   '各位',
#   '别信',
#   '回复',
#   '傻龟',
#   '呆呆地',
#   '好听话',
#   '傻龟',
#   '原来',
#   '你',
#   '是',
#   '个',
#   '大骗子',
#   '回复',
#   '温',
#   '大小',
#   '小鹏',
#   '走开',
#   '我',
#   '只是',
#   '被',
#   '骗',
#   '了'],
#  ['女子',
#   '乘',
#   '滴滴',
#   '顺风',
#   '车',
#   '遇害',
#   '温州',
#   '警方',
#   '两次',
#   '向',
#   '滴滴',
#   '索要',
#   '嫌犯',
#   '信息',
#   '被',
#   '拒',
#   '不',
#   '存在',
#   '没',
#   '车牌',
#   '不',
#   '立案',
#   '月',
#   '日',
#   '浙江',
#   '乐清',
#   '乘客',
#   '赵某',
#   '在',
#   '搭乘',
#   '滴滴',
#   '顺风',
#   '车时',
#   '被',
#   '司机',
#   '钟某',
#   '杀害',
#   '部分',
#   '网友',
#   '质疑',
#   '警方',
#   '在',
#   '侦破',
#   '此案',
#   '过程',
#   '中',
#   '接处警',
#   '工作',
#   '存在',
#   '问题',
#   '日',
#   '凌晨',
#   '温州',
#   '警方',
#   '通报',
#   '称',
#   '经',
#   '公安机关',
#   '调查',
#   '不',
#   '存在',
#   '没有',
#   '车牌号',
#   '和',
#   '司机',
#   '电话',
#   '不予',
#   '立案',
#   '的',
#   '情',
#   '抵制',
#   '滴滴',
#   '不',
#   '客气',
#   '这',
#   '滴滴',
#   '出行',
#   '简直',
#   '就是',
#   '违法',
#   '分子',
#   '的',
#   '保护伞',
#   '是',
#   '违法',
#   '分子',
#   '的',
#   '温床',
#   '不严',
#   '扫',
#   '滴滴',
#   '什么',
#   '安全感',
#   '获得',
#   '感',
#   '幸福感',
#   '都',
#   '是',
#   '空淡',
#   '强烈要求',
#   '有关',
#   '部门',
#   '严扫',
#   '滴滴',
#   '真牛',
#   '不',
#   '配合',
#   '警方',
#   '调查',
#   '支持',
#   '滴滴',
#   '下架',
#   '支持',
#   '滴滴',
#   '关门',
#   '滴滴',
#   '下架',
#   '不',
#   '提供',
#   '警官证',
#   '谁',
#   '知道',
#   '你',
#   '是',
#   '警察',
#   '中国',
#   '人',
#   '最',
#   '恐怖',
#   '的',
#   '是',
#   '什么',
#   '是',
#   '很',
#   '健忘',
#   '过',
#   '两天',
#   '大家',
#   '都',
#   '跟',
#   '没事',
#   '样',
#   '的',
#   '继续',
#   '叫',
#   '滴滴',
#   '那',
#   '你们',
#   '为啥',
#   '不',
#   '提供',
#   '警官证',
#   '滴滴',
#   '真的',
#   '有',
#   '反省',
#   '吗',
#   '我',
#   '觉得',
#   '没有',
#   '三次',
#   '索要',
#   '信息',
#   '前',
#   '两次',
#   '被',
#   '拒',
#   '第三次',
#   '出示',
#   '警官证',
#   '后',
#   '就',
#   '给',
#   '了',
#   '那',
#   '就是',
#   '前',
#   '两次',
#   '是因为',
#   '没',
#   '出示证件',
#   '滴滴',
#   '才',
#   '没',
#   '给',
#   '为什么',
#   '不',
#   '第一次',
#   '的',
#   '时候',
#   '就',
#   '出示证件',
#   '你',
#   '没',
#   '任何',
#   '证件',
#   '谁',
#   '知道',
#   '你',
#   '是',
#   '谁',
#   '报过警',
#   '每次',
#   '都',
#   '是',
#   '被',
#   '骂',
#   '或者',
#   '被',
#   '鄙视',
#   '拜拜',
#   '对',
#   '民营企业',
#   '的',
#   '垄断',
#   '很多',
#   '国人',
#   '的',
#   '容忍度',
#   '怎么',
#   '就',
#   '那么',
#   '大',
#   '了',
#   '金',
#   '权力',
#   '的',
#   '贪婪',
#   '比',
#   '公权力',
#   '贪腐',
#   '厉害',
#   '的',
#   '地方',
#   '就是',
#   '公权力',
#   '贪腐',
#   '非法',
#   '见',
#   '不得',
#   '光',
#   '总有',
#   '被',
#   '清算',
#   '的',
#   '时候',
#   '老百姓',
#   '可以',
#   '骂娘',
#   '甚至',
#   '反抗',
#   '金',
#   '权力',
#   '的',
#   '贪婪',
#   '则',
#   '往往',
#   '是',
#   '把',
#   '非法',
#   '不合理',
#   '不道德',
#   '的',
#   '事',
#   '合法化',
#   '了',
#   '堂而皇之',
#   '的',
#   '贪婪',
#   '老百姓',
#   '骂娘',
#   '的',
#   '资格',
#   '都',
#   '没有',
#   '有',
#   '啥',
#   '解释',
#   '的',
#   '天下',
#   '乌鸦',
#   '银行',
#   '失误',
#   '法院',
#   '判定',
#   '百姓',
#   '买单',
#   '辽宁',
#   '葫芦岛',
#   '年',
#   '贷款',
#   '业务',
#   '己',
#   '结清',
#   '年',
#   '又',
#   '天降',
#   '利息',
#   '未',
#   '通知',
#   '任何人',
#   '将',
#   '用户',
#   '拉',
#   '入',
#   '黑名单',
#   '这么',
#   '明显',
#   '的',
#   '错误',
#   '却',
#   '只字不提',
#   '一审',
#   '事实',
#   '已经',
#   '核实',
#   '非常',
#   '清楚',
#   '了',
#   '二审',
#   '无视',
#   '证据',
#   '强行',
#   '改判',
#   '老百姓',
#   '想',
#   '通过',
#   '正当',
#   '途径',
#   '维权',
#   '怎么',
#   '就',
#   '这么',
#   '难',
#   '怒',
#   '女孩',
#   '为什么',
#   '不发',
#   '定位',
#   '呢',
#   '女子',
#   '乘',
#   '滴滴',
#   '顺风',
#   '车',
#   '遇害',
#   '抵制',
#   '滴滴',
#   '为何',
#   '不',
#   '第一',
#   '时间',
#   '出示',
#   '警官证',
#   '还',
#   '解释',
#   '什么',
#   '呀',
#   '交管局',
#   '应该',
#   '取缔',
#   '拒',
#   '不',
#   '配合',
#   '的',
#   '滴滴',
#   '平台',
#   '运营',
#   '资格',
#   '短短',
#   '几年',
#   '两年',
#   '多',
#   '吧',
#   '滴滴',
#   '恶性事件',
#   '频发',
#   '拒绝',
#   '和',
#   '故意',
#   '拖延',
#   '屡见不鲜',
#   '雇佣',
#   '人员',
#   '问题',
#   '太',
#   '多',
#   '平台',
#   '主观',
#   '故意',
#   '变相',
#   '保护',
#   '犯罪分子',
#   '且',
#   '对',
#   '乘客',
#   '冷漠',
#   '无情',
#   '要',
#   '这样',
#   '的',
#   '价高',
#   '服务',
#   '次',
#   '的',
#   '面相',
#   '人民',
#   '群众',
#   '的',
#   '服务行业',
#   '干嘛',
#   '如果',
#   '滴滴',
#   '后台',
#   '通天',
#   '最好',
#   '老百姓',
#   '慎重',
#   '选择',
#   '这个',
#   '夺命',
#   '服务',
#   '都',
#   '懂',
#   '谁',
#   '还',
#   '还',
#   '没报',
#   '过警',
#   '不用',
#   '解释',
#   '都',
#   '是',
#   '无力',
#   '的',
#   '喜事',
#   '不宜',
#   '滴滴',
#   '敢',
#   '不',
#   '配合',
#   '警方',
#   '办案',
#   '这么',
#   '嚣张',
#   '已经',
#   '第二例',
#   '了',
#   '平台',
#   '为什么',
#   '不',
#   '关闭',
#   '看',
#   '了',
#   '好气',
#   '呀',
#   '滴滴',
#   '什么',
#   '时候',
#   '才能',
#   '重视',
#   '起来',
#   '也许',
#   '在',
#   '之前',
#   '那位',
#   '乘客',
#   '投诉',
#   '时能',
#   '重视',
#   '起来',
#   '死者',
#   '就',
#   '不会',
#   '遇害',
#   '也许',
#   '在',
#   '死者',
#   '朋友',
#   '第一次',
#   '给',
#   '滴滴',
#   '反映',
#   '时',
#   '滴滴',
#   '能',
#   '重视',
#   '起来',
#   '死者',
#   '或许',
#   '不会',
#   '遇害',
#   '也许',
#   '在',
#   '警方',
#   '介入',
#   '的',
#   '第一',
#   '时间',
#   '滴滴',
#   '能够',
#   '配合',
#   '死者',
#   '或许',
#   '就',
#   '不会',
#   '遇害',
#   '可是',
#   '没有',
#   '也许',
#   '真的',
#   '从',
#   '昨晚',
#   '到',
#   '现在',
#   '看见',
#   '这个',
#   '新闻',
#   '眼泪',
#   '还是',
#   '会',
#   '下来',
#   '这是',
#   '一条',
#   '命',
#   '呀',
#   '无论是',
#   '作为',
#   '知名',
#   '企业家',
#   '的',
#   '社会',
#   '责任',
#   '还是',
#   '滴滴',
#   '如此',
#   '体量',
#   '且',
#   '关乎',
#   '民生',
#   '的',
#   '大',
#   '公司',
#   '的',
#   '企业',
#   '社会',
#   '责任',
#   '滴滴',
#   '的',
#   '高管',
#   '都',
#   '应',
#   '对外',
#   '有',
#   '一个',
#   '明确',
#   '的',
#   '表态',
#   '此类',
#   '恶性事件',
#   '的',
#   '反复',
#   '发生',
#   '作为',
#   '企业家',
#   '本身',
#   '已',
#   '无法',
#   '与',
#   '之',
#   '隔离',
#   '推',
#   '推',
#   '推',
#   '希望',
#   '找个',
#   '让',
#   '人',
#   '信服',
#   '的',
#   '理由',
#   '好',
#   '吗',
#   '那',
#   '我',
#   '手机',
#   '丢',
#   '了',
#   '告诉',
#   '出警',
#   '人员',
#   '我',
#   '手机',
#   '有',
#   '定位',
#   '他们',
#   '就是',
#   '不',
#   '给',
#   '立案',
#   '很',
#   '明确',
#   '的',
#   '告诉',
#   '我',
#   '他们',
#   '不',
#   '负责',
#   '抓小偷',
#   '如果',
#   '你',
#   '我',
#   '抓来',
#   '他们',
#   '可以',
#   '帮忙',
#   '审问',
#   '我',
#   '抓',
#   '不来',
#   '他们',
#   '也',
#   '没',
#   '办法',
#   '警察',
#   '竟然',
#   '不',
#   '负责',
#   '抓小偷',
#   '我',
#   '小时候',
#   '书里',
#   '歌里',
#   '都',
#   '是',
#   '骗人',
#   '的',
#   '吧',
#   '歪',
#   '果仁',
#   '丢',
#   '了',
#   '辆',
#   '自行车',
#   '你们',
#   '屁颠',
#   '屁颠',
#   '的',
#   '去',
#   '找',
#   '以上',
#   '内容',
#   '不',
#   '针对',
#   '所有',
#   '警察',
#   '相信',
#   '有',
#   '好',
#   '的',
#   '存在',
#   '一',
#   '开始',
#   '就',
#   '误解',
#   '了',
#   '警方',
#   '这件',
#   '事',
#   '警方',
#   '没',
#   '做',
#   '错',
#   '做错',
#   '的',
#   '是',
#   '滴滴',
#   '滴滴',
#   '不',
#   '处理',
#   '前',
#   '一位',
#   '顾客',
#   '的',
#   '投诉',
#   '继续',
#   '给',
#   '司机',
#   '派单',
#   '出',
#   '了',
#   '事',
#   '不',
#   '积极',
#   '配合',
#   '警察',
#   '反而',
#   '自己',
#   '联系',
#   '司机',
#   '恕我直言',
#   '滴滴',
#   '就是',
#   '凶手',
#   '之一',
#   '呵呵',
#   '开始',
#   '互相',
#   '踢皮球',
#   '了',
#   '这个',
#   '问题',
#   '貌似',
#   '就是',
#   '报道',
#   '得不到',
#   '处理',
#   '啊',
#   '你',
#   '不',
#   '提供',
#   '警官证',
#   '为什么',
#   '要',
#   '给',
#   '你',
#   '要',
#   '那样',
#   '随便',
#   '都',
#   '能',
#   '要',
#   '到',
#   '别人',
#   '信息',
#   '干脆',
#   '上街',
#   '裸奔',
#   '警方',
#   '和',
#   '滴滴',
#   '都',
#   '有',
#   '责任',
#   '挖',
#   '鼻',
#   '把',
#   '滴滴',
#   '关',
#   '了',
#   '第一次',
#   '向',
#   '滴滴',
#   '索要',
#   '犯罪',
#   '嫌疑人',
#   '信息',
#   '时',
#   '为什么',
#   '不用',
#   '派出所',
#   '电话',
#   '为什么',
#   '不',
#   '出示',
#   '警官证',
#   '警察',
#   '依法',
#   '索要',
#   '信息',
#   '还',
#   '能',
#   '不',
#   '给',
#   '这么',
#   '面',
#   '的',
#   '警察',
#   '回家吧'],
#  ['傻',
#   '逼',
#   '媒体',
#   '济宁',
#   '学院',
#   '男生',
#   '因',
#   '分手',
#   '问题',
#   '将',
#   '女友',
#   '捅',
#   '死',
#   '两',
#   '人均',
#   '岁'],
#  ...]

# %%
for index,row in testset.iterrows():
    testset.at[index,'content']=clear(testset.at[index,'content'])
    testset.at[index,'comment_all']=clear(testset.at[index,'comment_all'])
testset
# Out:
#                                                 content  \
# id
# 0     [昨天, 在家, 楼下, 网点, 改, 了, 全, 渠道, 手机号, 去, 单位, 楼下, ...
# 1     [婆婆, 为, 维护, 出轨, 儿子, 虐待, 儿媳, 致其成, 骷髅, 杨, 女士, 发现...
# 2     [各位, 有, 家长, 反映, 今天, 中午, 放学, 时, 有, 学生, 遇到, 开, 小...
# 3     [帮忙, 发, 一条, 救命, 信息, 急需, 阴性, 血, 救命之恩, 必有, 重谢, 电...
# 4           [逃犯, 克星, 立新功, 张学友, 金华, 演唱会, 又, 有, 逃犯, 被, 抓]
# ...                                                 ...
# 9977  [历史, 影像, 中英街, 边界, 石碑, 上, 殖民, 香港, 的, 英国, 警官, 与,...
# 9978  [开学, 季, 我们, 进校园, 新年, 已过, 转眼, 又, 到, 了, 孩子, 们, 开...
# 9979  [一名, 中学生, 叫, 周榆棍, 岁, 请, 速回, 平山县, 医院, 妈妈, 伤, 的,...
# 9980  [艺龙, 真是, 恶心, 人, 我, 在, 艺龙定, 了, 好, 几次, 宾馆, 每次, 都...
# 9981  [学生家长, 捡, 到, 一个, 高考, 准考证, 谁, 认识, 通知, 下, 别, 耽误,...
#
#                                             comment_all
# id
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     [此, 为, 虚假, 消息, 请勿, 转发, 虚假, 消息, 回复, 花自, 漂零, 的, ...
# 4                                                  None
# ...                                                 ...
# 9977                                               None
# 9978                                               None
# 9979                                               None
# 9980  [您好, 感谢, 反馈, 会, 尽快, 与, 您, 联系, 的, 时候, 是, 问, 清楚,...
# 9981  [白, 较瘦, 键, 大鹏, 看, 天下, 转发, 下, 吧, 别, 耽误, 孩子, 高考,...
#
# [9982 rows x 2 columns]

# %%
dataset.to_pickle('split_dataset')
testset.to_pickle('split_testset')

# %% [markdown]
# 先用tf-idf方法做出一个base-line，然后再考虑用transformer。
# \\干，还是先想想词嵌入吧，CBOW和N-grams都不错。

# %% [markdown]
# path_translated='D:\\pycode\\jupyter\\dataset_news\\ChineseWordVectors\\evaluation\\testsets\\CA_translated\\ca_translated.txt'
# path_morhological='D:\\pycode\\jupyter\\dataset_news\\ChineseWordVectors\\evaluation\\testsets\\CA8\morhological.txt'
# path_word='D:\\pycode\\jupyter\\dataset_news\\ChineseWordVectors\\evaluation\\testsets\\wordset.txt'
# filenames=[path_translated,path_morhological,path_semantic]
# path_sogou='D:\\pycode\\jupyter\\dataset_news\\News'
# with open(path_word,"r",encoding="utf-8") as f:
#     text=f.readlines()
# for str1 in text:
#     str1.strip("\n")
#     str1.split(" ")
# text=[str1.strip("\n").split(" ")for str1 in text]
# text

# %% [markdown]
# 这里做了一个小demo。可以用得

# %%
from gensim.models import FastText

# %% [markdown]
# sentences：可以是一个list，对于大语料集，建议使用BrownCorpus,Text8Corpus或LineSentence构建。
#
# sg： 用于设置训练算法，默认为0，对应CBOW算法；sg=1则采用skip-gram算法。
#
# size：是指特征向量的维度，默认为100。大的size需要更多的训练数据,但是效果会更好. 推荐值为几十到几百。
#
# window：表示当前词与预测词在一个句子中的最大距离是多少
#
# alpha: 是学习速率
#
# seed：用于随机数发生器。与初始化词向量有关。
#
# min_count: 可以对字典做截断. 词频少于min_count次数的单词会被丢弃掉, 默认值为5
#
# max_vocab_size: 设置词向量构建期间的RAM限制。如果所有独立单词个数超过这个，则就消除掉其中最不频繁的一个。每一千万个单词需要大约1GB的RAM。设置成None则没有限制。
#
# sample: 高频词汇的随机降采样的配置阈值，默认为1e-3，范围是(0,1e-5)
#
# workers参数控制训练的并行数。
#
# hs: 如果为1则会采用hierarchical softmax技巧。如果设置为0（defaut），则negative sampling会被使用。
#
# negative: 如果>0,则会采用negativesamping，用于设置多少个noise words
#
# cbow_mean: 如果为0，则采用上下文词向量的和，如果为1（defaut）则采用均值。只有使用CBOW的时候才起作用。
#
# hashfxn： hash函数来初始化权重。默认使用python的hash函数
#
# iter： 迭代次数，默认为5
#
# trim_rule： 用于设置词汇表的整理规则，指定那些单词要留下，哪些要被删除。可以设置为None（min_count会被使用）或者一个接受()并返回RU·E_DISCARD,uti·s.RU·E_KEEP或者uti·s.RU·E_DEFAU·T的函数。
#
# sorted_vocab： 如果为1（defaut），则在分配word index 的时候会先对单词基于频率降序排序。
#
# batch_words：每一批的传递给线程的单词的数量，默认为10000

# %%
model2=FastText(dataset2, sg=1,vector_size=100, window=5, min_count=1, workers=4)

# %% [markdown]
# model2.wv.most_similar("吴官骏")

# %% [markdown]
# print(model2.wv.similarity('陈逸', '扶贫'))

# %% [markdown]
# len(model2.wv['代码'])

# %% [markdown]
# 接下来要做的事：整理成语料库，然后放入txt文档，然后放入model训练。生成预训练模型。
# <p>数据训练部分已经完成。看上面几行示例就可以获得相应的词向量。接下来完成Embedding部分。

# %%
import numpy as np
c=[]
for sequence in dataset2:
    b=[]
    for word in sequence:
        a=model2.wv[word]
        b.append(a)
    c.append(b)
data_numpy=np.array(c)
# Out:
# /var/folders/34/5ls3qb4j0rl0kbsw8j22d1_w0000gn/T/ipykernel_33188/738509728.py:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   data_numpy=np.array(c)

# %%
data_numpy
# Out:
# array([list([array([ 0.01111047,  0.15573478,  0.5394658 ,  0.5776898 , -0.20704894,
#        -0.53447825, -0.27937084,  0.6725365 , -0.0279234 ,  0.351369  ,
#         0.10360638, -0.26450968,  0.05848536,  0.37791204,  0.40422088,
#         0.23985182,  0.31472486, -0.6536147 , -0.47137547, -0.8082617 ,
#        -0.1389393 ,  0.03160868,  0.15291962,  0.4206323 , -0.21481644,
#         0.42859402, -0.39408174, -0.28464338, -0.11427695,  0.6978684 ,
#         0.6890319 , -0.6084487 ,  0.04778454,  0.04752538, -0.6574274 ,
#         0.24576247,  0.10789709, -0.20991416, -0.19647367, -0.5293797 ,
#         0.06690597,  0.36516914, -0.42938083,  0.841566  , -0.14935076,
#         0.54856694, -0.52987754,  0.09245888, -0.23080194, -0.41130668,
#         0.5200139 , -0.21514294, -0.71834755,  0.12149673,  0.6412147 ,
#         0.2992021 ,  0.1267975 , -0.19855747, -0.39989787, -0.00509983,
#         0.22837617,  0.517133  , -0.48282552,  0.04276463, -0.2738971 ,
#         0.76294523,  0.24133424,  0.15804137, -0.6919345 , -0.3141236 ,
#         0.3013112 ,  0.35095122,  0.4911087 , -0.28784543,  0.22950724,
#         0.6117733 ,  0.03875431,  0.06434407,  0.04492498, -0.6571265 ,
#        -0.02862473, -0.30580762,  0.10524298,  0.5963325 ,  0.8534259 ,
#        -0.03490096,  0.14888035,  0.0649315 ,  0.41865274, -0.9416711 ,
#         0.5573688 ,  0.04631122, -0.46945062,  0.5268466 ,  0.51804   ,
#         0.08154424, -0.23756231, -0.09679646, -0.28015798, -0.19731995],
#       dtype=float32), array([ 0.11431518,  0.23817366,  0.24856326,  0.28906506, -0.27047357,
#        -0.2410176 ,  0.01054502,  0.27891308, -0.1619781 ,  0.268193  ,
#        -0.0599568 ,  0.00326295,  0.10046388,  0.4100454 ,  0.15388155,
#         0.35343528,  0.4771939 , -0.25539532,  0.0366104 , -0.81113845,
